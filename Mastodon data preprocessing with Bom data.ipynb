# %% [markdown]
# # Harvest data from Mastodon

# %%
from mastodon import Mastodon
import json, time
import pandas as pd
import requests

# For initialization, some server/feature/operation does not need token, while for others, apply for token
m = Mastodon(
    api_base_url=f'https://mastodon.au'
    # use the url of the server such as https://aus.social for https://aus.social/explore
)

# Use timer or loop to achieve streaming harvester, be ware of the frequency
lastid = m.timeline(timeline='public', since_id=None, limit=1, remote=True)[0]['id']
time.sleep(10)
mastodon_data = m.timeline(timeline='public', since_id=lastid, remote=True)
for i in range(len(mastodon_data)):
    print(f"{mastodon_data[i].account.acct}: {mastodon_data[i].id}")
# Out:
# anandamide@dataare.cool: 112421508232889124
# Galehawk@toot.community: 112421507979733193
# dachengzi@go5.dev: 112421507878887151

# %% [markdown]
# # Harvest data from BoM

# %%
bom_data = requests.get('http://reg.bom.gov.au/fwo/IDV60901/IDV60901.95936.json').json()['observations']['data']
for i in range(len(bom_data)):
    print(f"{bom_data[i]['local_date_time']} air_temp: {bom_data[i]['air_temp']},apparent_t: {bom_data[i]['apparent_t']},vis_km:{bom_data[i]['vis_km']}, rain_trace:{bom_data[i]['rain_trace']}, rel_hum:{bom_data[i]['rel_hum']}, wind_spd_kmh: {bom_data[i]['wind_spd_kmh']} ")
# Out:
# 11/06:00pm air_temp: 16.1,apparent_t: 15.1,vis_km:10, rain_trace:0.0, rel_hum:69, wind_spd_kmh: 6
# 11/05:30pm air_temp: 16.5,apparent_t: 15.0,vis_km:10, rain_trace:0.0, rel_hum:67, wind_spd_kmh: 9
# 11/05:00pm air_temp: 16.9,apparent_t: 16.0,vis_km:10, rain_trace:0.0, rel_hum:66, wind_spd_kmh: 6
# 11/04:30pm air_temp: 17.3,apparent_t: 15.4,vis_km:10, rain_trace:0.0, rel_hum:64, wind_spd_kmh: 11
# 11/04:00pm air_temp: 17.7,apparent_t: 16.1,vis_km:10, rain_trace:0.0, rel_hum:62, wind_spd_kmh: 9
# 11/03:30pm air_temp: 17.8,apparent_t: 15.5,vis_km:10, rain_trace:0.0, rel_hum:62, wind_spd_kmh: 13
# 11/03:00pm air_temp: 18.1,apparent_t: 15.8,vis_km:10, rain_trace:0.0, rel_hum:61, wind_spd_kmh: 13
# 11/02:30pm air_temp: 18.5,apparent_t: 16.3,vis_km:10, rain_trace:0.0, rel_hum:61, wind_spd_kmh: 13
# 11/02:00pm air_temp: 18.6,apparent_t: 16.8,vis_km:10, rain_trace:0.0, rel_hum:61, wind_spd_kmh: 11
# 11/01:30pm air_temp: 18.7,apparent_t: 16.6,vis_km:10, rain_trace:0.0, rel_hum:62, wind_spd_kmh: 13
# 11/01:00pm air_temp: 19.0,apparent_t: 18.2,vis_km:10, rain_trace:0.0, rel_hum:63, wind_spd_kmh: 7
# 11/12:30pm air_temp: 18.6,apparent_t: 17.7,vis_km:10, rain_trace:0.0, rel_hum:63, wind_spd_kmh: 7
# 11/12:00pm air_temp: 18.9,apparent_t: 18.4,vis_km:10, rain_trace:0.0, rel_hum:67, wind_spd_kmh: 7
# 11/11:30am air_temp: 18.6,apparent_t: 17.5,vis_km:10, rain_trace:0.0, rel_hum:66, wind_spd_kmh: 9
# 11/11:00am air_temp: 17.4,apparent_t: 16.5,vis_km:10, rain_trace:0.0, rel_hum:73, wind_spd_kmh: 9
# 11/10:30am air_temp: 16.8,apparent_t: 15.8,vis_km:10, rain_trace:0.0, rel_hum:75, wind_spd_kmh: 9
# 11/10:00am air_temp: 16.2,apparent_t: 15.3,vis_km:10, rain_trace:0.0, rel_hum:80, wind_spd_kmh: 9
# 11/09:30am air_temp: 15.6,apparent_t: 16.7,vis_km:10, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 4
# 11/09:00am air_temp: 14.2,apparent_t: 15.5,vis_km:10, rain_trace:1.8, rel_hum:100, wind_spd_kmh: 0
# 11/08:30am air_temp: 13.6,apparent_t: 14.7,vis_km:10, rain_trace:1.8, rel_hum:100, wind_spd_kmh: 0
# 11/08:00am air_temp: 13.2,apparent_t: 14.2,vis_km:10, rain_trace:1.8, rel_hum:100, wind_spd_kmh: 0
# 11/07:30am air_temp: 13.1,apparent_t: 14.1,vis_km:10, rain_trace:1.8, rel_hum:100, wind_spd_kmh: 0
# 11/07:06am air_temp: 12.9,apparent_t: 13.8,vis_km:10, rain_trace:1.8, rel_hum:100, wind_spd_kmh: 0
# 11/07:00am air_temp: 13.0,apparent_t: 13.9,vis_km:9, rain_trace:1.8, rel_hum:100, wind_spd_kmh: 0
# 11/06:30am air_temp: 13.1,apparent_t: 14.1,vis_km:3, rain_trace:1.8, rel_hum:100, wind_spd_kmh: 0
# 11/06:00am air_temp: 13.4,apparent_t: 14.5,vis_km:4, rain_trace:1.6, rel_hum:100, wind_spd_kmh: 0
# 11/05:30am air_temp: 13.6,apparent_t: 14.7,vis_km:5, rain_trace:1.6, rel_hum:100, wind_spd_kmh: 0
# 11/05:00am air_temp: 13.6,apparent_t: 14.7,vis_km:8, rain_trace:1.6, rel_hum:100, wind_spd_kmh: 0
# 11/04:40am air_temp: 13.7,apparent_t: 14.9,vis_km:7, rain_trace:1.6, rel_hum:100, wind_spd_kmh: 0
# 11/04:30am air_temp: 13.8,apparent_t: 15.0,vis_km:10, rain_trace:1.4, rel_hum:100, wind_spd_kmh: 0
# 11/04:01am air_temp: 13.6,apparent_t: 14.7,vis_km:10, rain_trace:1.0, rel_hum:100, wind_spd_kmh: 0
# 11/04:00am air_temp: 13.6,apparent_t: 14.7,vis_km:9, rain_trace:1.0, rel_hum:100, wind_spd_kmh: 0
# 11/03:40am air_temp: 13.6,apparent_t: 14.7,vis_km:7, rain_trace:0.8, rel_hum:100, wind_spd_kmh: 0
# 11/03:30am air_temp: 13.7,apparent_t: 14.9,vis_km:9, rain_trace:0.8, rel_hum:100, wind_spd_kmh: 0
# 11/03:00am air_temp: 13.5,apparent_t: 14.6,vis_km:8, rain_trace:0.6, rel_hum:100, wind_spd_kmh: 0
# 11/02:30am air_temp: 13.5,apparent_t: 14.6,vis_km:10, rain_trace:0.6, rel_hum:100, wind_spd_kmh: 0
# 11/02:00am air_temp: 13.4,apparent_t: 14.5,vis_km:10, rain_trace:0.6, rel_hum:100, wind_spd_kmh: 0
# 11/01:30am air_temp: 13.4,apparent_t: 14.5,vis_km:10, rain_trace:0.6, rel_hum:100, wind_spd_kmh: 0
# 11/01:00am air_temp: 13.5,apparent_t: 14.6,vis_km:10, rain_trace:0.6, rel_hum:100, wind_spd_kmh: 0
# 11/12:49am air_temp: 13.5,apparent_t: 14.6,vis_km:10, rain_trace:0.6, rel_hum:100, wind_spd_kmh: 0
# 11/12:30am air_temp: 13.6,apparent_t: 14.7,vis_km:7, rain_trace:0.6, rel_hum:100, wind_spd_kmh: 0
# 11/12:00am air_temp: 13.7,apparent_t: 14.9,vis_km:10, rain_trace:0.6, rel_hum:100, wind_spd_kmh: 0
# 10/11:30pm air_temp: 13.8,apparent_t: 15.0,vis_km:10, rain_trace:0.6, rel_hum:100, wind_spd_kmh: 0
# 10/11:00pm air_temp: 14.0,apparent_t: 15.3,vis_km:10, rain_trace:0.6, rel_hum:100, wind_spd_kmh: 0
# 10/10:30pm air_temp: 14.2,apparent_t: 15.5,vis_km:10, rain_trace:0.6, rel_hum:100, wind_spd_kmh: 0
# 10/10:00pm air_temp: 14.3,apparent_t: 15.7,vis_km:10, rain_trace:0.6, rel_hum:100, wind_spd_kmh: 0
# 10/09:30pm air_temp: 14.4,apparent_t: 15.8,vis_km:10, rain_trace:0.6, rel_hum:100, wind_spd_kmh: 0
# 10/09:00pm air_temp: 14.4,apparent_t: 15.8,vis_km:10, rain_trace:0.6, rel_hum:100, wind_spd_kmh: 0
# 10/08:30pm air_temp: 14.5,apparent_t: 15.2,vis_km:10, rain_trace:0.6, rel_hum:100, wind_spd_kmh: 4
# 10/08:00pm air_temp: 14.7,apparent_t: 15.1,vis_km:10, rain_trace:0.6, rel_hum:100, wind_spd_kmh: 6
# 10/07:30pm air_temp: 14.8,apparent_t: 16.0,vis_km:10, rain_trace:0.6, rel_hum:100, wind_spd_kmh: 2
# 10/07:19pm air_temp: 14.8,apparent_t: 16.4,vis_km:10, rain_trace:0.6, rel_hum:100, wind_spd_kmh: 0
# 10/07:00pm air_temp: 14.7,apparent_t: 15.8,vis_km:5, rain_trace:0.6, rel_hum:100, wind_spd_kmh: 2
# 10/06:30pm air_temp: 15.1,apparent_t: 16.8,vis_km:6, rain_trace:0.6, rel_hum:100, wind_spd_kmh: 0
# 10/06:00pm air_temp: 15.3,apparent_t: 17.0,vis_km:6, rain_trace:0.6, rel_hum:100, wind_spd_kmh: 0
# 10/05:55pm air_temp: 15.3,apparent_t: 17.0,vis_km:7, rain_trace:0.6, rel_hum:100, wind_spd_kmh: 0
# 10/05:30pm air_temp: 15.5,apparent_t: 17.3,vis_km:10, rain_trace:0.4, rel_hum:100, wind_spd_kmh: 0
# 10/05:00pm air_temp: 15.6,apparent_t: 17.4,vis_km:10, rain_trace:0.4, rel_hum:99, wind_spd_kmh: 0
# 10/04:30pm air_temp: 15.7,apparent_t: 17.0,vis_km:10, rain_trace:0.2, rel_hum:96, wind_spd_kmh: 2
# 10/04:00pm air_temp: 15.8,apparent_t: 16.6,vis_km:10, rain_trace:0.2, rel_hum:93, wind_spd_kmh: 4
# 10/03:30pm air_temp: 16.1,apparent_t: 16.4,vis_km:10, rain_trace:0.2, rel_hum:90, wind_spd_kmh: 6
# 10/03:00pm air_temp: 16.1,apparent_t: 16.3,vis_km:10, rain_trace:0.2, rel_hum:89, wind_spd_kmh: 6
# 10/02:30pm air_temp: 16.5,apparent_t: 16.2,vis_km:10, rain_trace:0.2, rel_hum:87, wind_spd_kmh: 9
# 10/02:00pm air_temp: 16.7,apparent_t: 17.0,vis_km:10, rain_trace:0.2, rel_hum:87, wind_spd_kmh: 6
# 10/01:30pm air_temp: 16.7,apparent_t: 17.8,vis_km:10, rain_trace:0.2, rel_hum:87, wind_spd_kmh: 2
# 10/01:00pm air_temp: 16.6,apparent_t: 17.9,vis_km:10, rain_trace:0.2, rel_hum:85, wind_spd_kmh: 0
# 10/12:30pm air_temp: 16.3,apparent_t: 16.9,vis_km:10, rain_trace:0.2, rel_hum:88, wind_spd_kmh: 4
# 10/12:00pm air_temp: 16.1,apparent_t: 16.5,vis_km:10, rain_trace:0.2, rel_hum:92, wind_spd_kmh: 6
# 10/11:30am air_temp: 15.7,apparent_t: 17.2,vis_km:10, rain_trace:0.2, rel_hum:93, wind_spd_kmh: 0
# 10/11:00am air_temp: 15.5,apparent_t: 17.2,vis_km:10, rain_trace:0.2, rel_hum:98, wind_spd_kmh: 0
# 10/10:30am air_temp: 15.6,apparent_t: 17.2,vis_km:10, rain_trace:0.2, rel_hum:96, wind_spd_kmh: 0
# 10/10:00am air_temp: 15.4,apparent_t: 17.0,vis_km:10, rain_trace:0.2, rel_hum:97, wind_spd_kmh: 0
# 10/09:30am air_temp: 14.7,apparent_t: 16.2,vis_km:10, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 10/09:00am air_temp: 14.0,apparent_t: 15.3,vis_km:10, rain_trace:14.0, rel_hum:100, wind_spd_kmh: 0
# 10/08:45am air_temp: 13.7,apparent_t: 14.9,vis_km:9, rain_trace:14.0, rel_hum:100, wind_spd_kmh: 0
# 10/08:30am air_temp: 13.4,apparent_t: 14.5,vis_km:7, rain_trace:14.0, rel_hum:100, wind_spd_kmh: 0
# 10/08:00am air_temp: 13.2,apparent_t: 14.2,vis_km:5, rain_trace:14.0, rel_hum:100, wind_spd_kmh: 0
# 10/07:30am air_temp: 13.3,apparent_t: 14.3,vis_km:5, rain_trace:14.0, rel_hum:100, wind_spd_kmh: 0
# 10/07:00am air_temp: 13.5,apparent_t: 14.6,vis_km:4, rain_trace:14.0, rel_hum:100, wind_spd_kmh: 0
# 10/06:48am air_temp: 13.6,apparent_t: 14.7,vis_km:7, rain_trace:14.0, rel_hum:100, wind_spd_kmh: 0
# 10/06:30am air_temp: 13.6,apparent_t: 14.7,vis_km:10, rain_trace:14.0, rel_hum:100, wind_spd_kmh: 0
# 10/06:00am air_temp: 13.6,apparent_t: 14.4,vis_km:8, rain_trace:14.0, rel_hum:100, wind_spd_kmh: 2
# 10/05:34am air_temp: 13.6,apparent_t: 13.4,vis_km:9, rain_trace:14.0, rel_hum:100, wind_spd_kmh: 7
# 10/05:30am air_temp: 13.6,apparent_t: 13.4,vis_km:9, rain_trace:14.0, rel_hum:100, wind_spd_kmh: 7
# 10/05:00am air_temp: 13.6,apparent_t: 14.7,vis_km:4, rain_trace:14.0, rel_hum:100, wind_spd_kmh: 0
# 10/04:30am air_temp: 13.6,apparent_t: 14.7,vis_km:3, rain_trace:14.0, rel_hum:100, wind_spd_kmh: 0
# 10/04:00am air_temp: 13.5,apparent_t: 13.8,vis_km:0.8, rain_trace:13.2, rel_hum:100, wind_spd_kmh: 4
# 10/03:30am air_temp: 13.6,apparent_t: 14.7,vis_km:3, rain_trace:11.0, rel_hum:100, wind_spd_kmh: 0
# 10/03:00am air_temp: 13.6,apparent_t: 14.7,vis_km:2, rain_trace:9.2, rel_hum:100, wind_spd_kmh: 0
# 10/02:30am air_temp: 13.7,apparent_t: 13.5,vis_km:5, rain_trace:6.6, rel_hum:100, wind_spd_kmh: 7
# 10/02:00am air_temp: 13.9,apparent_t: 14.0,vis_km:7, rain_trace:5.8, rel_hum:100, wind_spd_kmh: 6
# 10/01:30am air_temp: 13.8,apparent_t: 14.6,vis_km:4, rain_trace:5.8, rel_hum:100, wind_spd_kmh: 2
# 10/01:00am air_temp: 13.8,apparent_t: 14.6,vis_km:4, rain_trace:5.6, rel_hum:100, wind_spd_kmh: 2
# 10/12:52am air_temp: 13.9,apparent_t: 14.8,vis_km:7, rain_trace:5.6, rel_hum:100, wind_spd_kmh: 2
# 10/12:47am air_temp: 13.9,apparent_t: 14.8,vis_km:9, rain_trace:5.6, rel_hum:100, wind_spd_kmh: 2
# 10/12:30am air_temp: 13.7,apparent_t: 14.9,vis_km:3, rain_trace:5.6, rel_hum:100, wind_spd_kmh: 0
# 10/12:00am air_temp: 13.8,apparent_t: 15.0,vis_km:9, rain_trace:5.6, rel_hum:100, wind_spd_kmh: 0
# 09/11:30pm air_temp: 13.9,apparent_t: 15.1,vis_km:2, rain_trace:4.6, rel_hum:100, wind_spd_kmh: 0
# 09/11:00pm air_temp: 14.3,apparent_t: 14.9,vis_km:4, rain_trace:2.8, rel_hum:100, wind_spd_kmh: 4
# 09/10:39pm air_temp: 14.5,apparent_t: 14.6,vis_km:7, rain_trace:1.2, rel_hum:100, wind_spd_kmh: 7
# 09/10:30pm air_temp: 14.5,apparent_t: 14.2,vis_km:10, rain_trace:0.6, rel_hum:100, wind_spd_kmh: 9
# 09/10:00pm air_temp: 14.7,apparent_t: 15.1,vis_km:10, rain_trace:0.4, rel_hum:100, wind_spd_kmh: 6
# 09/09:30pm air_temp: 14.2,apparent_t: 14.8,vis_km:10, rain_trace:0.2, rel_hum:100, wind_spd_kmh: 4
# 09/09:25pm air_temp: 14.2,apparent_t: 15.2,vis_km:9, rain_trace:0.2, rel_hum:100, wind_spd_kmh: 2
# 09/09:00pm air_temp: 14.0,apparent_t: 15.3,vis_km:6, rain_trace:0.2, rel_hum:100, wind_spd_kmh: 0
# 09/08:30pm air_temp: 14.0,apparent_t: 14.5,vis_km:6, rain_trace:0.2, rel_hum:100, wind_spd_kmh: 4
# 09/08:00pm air_temp: 14.0,apparent_t: 14.9,vis_km:5, rain_trace:0.2, rel_hum:100, wind_spd_kmh: 2
# 09/07:30pm air_temp: 14.0,apparent_t: 15.2,vis_km:7, rain_trace:0.0, rel_hum:99, wind_spd_kmh: 0
# 09/07:13pm air_temp: 14.1,apparent_t: 15.3,vis_km:7, rain_trace:0.0, rel_hum:98, wind_spd_kmh: 0
# 09/07:00pm air_temp: 14.3,apparent_t: 15.3,vis_km:8, rain_trace:0.0, rel_hum:94, wind_spd_kmh: 0
# 09/06:30pm air_temp: 14.5,apparent_t: 15.0,vis_km:10, rain_trace:0.0, rel_hum:90, wind_spd_kmh: 2
# 09/06:00pm air_temp: 14.6,apparent_t: 15.2,vis_km:10, rain_trace:0.0, rel_hum:91, wind_spd_kmh: 2
# 09/05:30pm air_temp: 14.6,apparent_t: 14.3,vis_km:9, rain_trace:0.0, rel_hum:89, wind_spd_kmh: 6
# 09/05:00pm air_temp: 15.2,apparent_t: 14.7,vis_km:9, rain_trace:0.0, rel_hum:85, wind_spd_kmh: 7
# 09/04:30pm air_temp: 15.8,apparent_t: 16.6,vis_km:10, rain_trace:0.0, rel_hum:82, wind_spd_kmh: 0
# 09/04:00pm air_temp: 16.0,apparent_t: 16.5,vis_km:10, rain_trace:0.0, rel_hum:81, wind_spd_kmh: 2
# 09/03:30pm air_temp: 16.0,apparent_t: 15.8,vis_km:10, rain_trace:0.0, rel_hum:82, wind_spd_kmh: 6
# 09/03:00pm air_temp: 16.0,apparent_t: 15.5,vis_km:10, rain_trace:0.0, rel_hum:81, wind_spd_kmh: 7
# 09/02:30pm air_temp: 16.2,apparent_t: 16.4,vis_km:10, rain_trace:0.0, rel_hum:82, wind_spd_kmh: 4
# 09/02:00pm air_temp: 15.7,apparent_t: 16.6,vis_km:10, rain_trace:0.0, rel_hum:84, wind_spd_kmh: 0
# 09/01:30pm air_temp: 15.2,apparent_t: 15.4,vis_km:10, rain_trace:0.0, rel_hum:88, wind_spd_kmh: 4
# 09/01:00pm air_temp: 14.8,apparent_t: 14.9,vis_km:10, rain_trace:0.0, rel_hum:88, wind_spd_kmh: 4
# 09/12:30pm air_temp: 14.9,apparent_t: 14.7,vis_km:10, rain_trace:0.0, rel_hum:88, wind_spd_kmh: 6
# 09/12:00pm air_temp: 14.8,apparent_t: 14.3,vis_km:10, rain_trace:0.0, rel_hum:86, wind_spd_kmh: 7
# 09/11:30am air_temp: 15.2,apparent_t: 15.7,vis_km:10, rain_trace:0.0, rel_hum:85, wind_spd_kmh: 2
# 09/11:00am air_temp: 14.9,apparent_t: 14.3,vis_km:10, rain_trace:0.0, rel_hum:84, wind_spd_kmh: 7
# 09/10:30am air_temp: 14.6,apparent_t: 15.3,vis_km:10, rain_trace:0.0, rel_hum:85, wind_spd_kmh: 0
# 09/10:00am air_temp: 13.8,apparent_t: 14.1,vis_km:10, rain_trace:0.0, rel_hum:90, wind_spd_kmh: 2
# 09/09:30am air_temp: 13.5,apparent_t: 14.4,vis_km:10, rain_trace:0.0, rel_hum:97, wind_spd_kmh: 0
# 09/09:00am air_temp: 12.7,apparent_t: 13.5,vis_km:10, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 09/08:30am air_temp: 12.1,apparent_t: 12.0,vis_km:10, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 4
# 09/08:27am air_temp: 12.0,apparent_t: 12.2,vis_km:9, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 2
# 09/08:00am air_temp: 11.2,apparent_t: 11.6,vis_km:8, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 09/07:30am air_temp: 10.9,apparent_t: 11.2,vis_km:5, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 09/07:00am air_temp: 10.6,apparent_t: 10.8,vis_km:4, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 09/06:30am air_temp: 10.4,apparent_t: 10.6,vis_km:5, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 09/06:00am air_temp: 10.2,apparent_t: 10.3,vis_km:4, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 09/05:30am air_temp: 10.0,apparent_t: 10.1,vis_km:3, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 09/05:00am air_temp: 9.9,apparent_t: 9.9,vis_km:4, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 09/04:30am air_temp: 9.9,apparent_t: 9.9,vis_km:3, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 09/04:00am air_temp: 10.1,apparent_t: 10.2,vis_km:4, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 09/03:30am air_temp: 10.2,apparent_t: 10.3,vis_km:4, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 09/03:00am air_temp: 10.3,apparent_t: 10.4,vis_km:4, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 09/02:30am air_temp: 10.0,apparent_t: 10.1,vis_km:3, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 09/02:00am air_temp: 9.9,apparent_t: 9.9,vis_km:3, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 09/01:30am air_temp: 10.0,apparent_t: 10.1,vis_km:4, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 09/01:00am air_temp: 10.2,apparent_t: 10.3,vis_km:4, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 09/12:30am air_temp: 10.3,apparent_t: 10.4,vis_km:3, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 09/12:00am air_temp: 10.6,apparent_t: 10.8,vis_km:4, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 08/11:30pm air_temp: 10.9,apparent_t: 11.2,vis_km:5, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 08/11:00pm air_temp: 11.3,apparent_t: 11.7,vis_km:7, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 08/10:59pm air_temp: 11.3,apparent_t: 11.7,vis_km:7, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 08/10:30pm air_temp: 11.6,apparent_t: 12.1,vis_km:9, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 08/10:18pm air_temp: 11.6,apparent_t: 12.1,vis_km:10, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 08/10:04pm air_temp: 11.6,apparent_t: 12.1,vis_km:7, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 08/10:00pm air_temp: 11.6,apparent_t: 12.1,vis_km:9, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 08/09:30pm air_temp: 11.9,apparent_t: 12.5,vis_km:10, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 08/09:00pm air_temp: 12.2,apparent_t: 12.8,vis_km:8, rain_trace:0.0, rel_hum:99, wind_spd_kmh: 0
# 08/08:30pm air_temp: 12.6,apparent_t: 13.2,vis_km:10, rain_trace:0.0, rel_hum:96, wind_spd_kmh: 0
# 08/08:00pm air_temp: 13.3,apparent_t: 14.0,vis_km:10, rain_trace:0.0, rel_hum:93, wind_spd_kmh: 0
# 08/07:30pm air_temp: 13.6,apparent_t: 14.3,vis_km:10, rain_trace:0.0, rel_hum:91, wind_spd_kmh: 0
# 08/07:00pm air_temp: 13.8,apparent_t: 14.5,vis_km:10, rain_trace:0.0, rel_hum:90, wind_spd_kmh: 0
# 08/06:30pm air_temp: 14.0,apparent_t: 14.6,vis_km:10, rain_trace:0.0, rel_hum:88, wind_spd_kmh: 0

# %% [markdown]
# # Data preprocessing

# %%
mas_df = pd.DataFrame(mastodon_data)

# %%
import geopandas as gpd
import random
from shapely.geometry import Point


melbourne_area = gpd.read_file("melbourne.geojson")
melbourne_polygon = melbourne_area.geometry.unary_union

def generate_random_points_in_polygon(poly, num_points):
    minx, miny, maxx, maxy = poly.bounds
    points = []
    while len(points) < num_points:
        p = Point(random.uniform(minx, maxx), random.uniform(miny, maxy))
        if poly.contains(p):
            points.append(p)
    return points

num = len(mas_df)
random_points = generate_random_points_in_polygon(melbourne_polygon, num)

x_coords = [point.x for point in random_points]
y_coords = [point.y for point in random_points]

mas_df['longitude'] = x_coords
mas_df['latitude'] = y_coords

# %%
mas_df = mas_df[['created_at', 'content', 'longitude', 'latitude']]
mas_df
# Out:
#                  created_at  \
# 0 2024-05-11 08:27:53+00:00
# 1 2024-05-11 08:27:55+00:00
# 2 2024-05-11 08:27:40+00:00
#
#                                              content   longitude   latitude
# 0  <p>Today feels like a good day to see Challeng...  145.013062 -37.902176
# 1  <p><a href="https://www.youtube.com/watch?v=jD...  144.952333 -37.830720
# 2       <p>手机里看到的。肉眼能看到光在跳舞，人类的眼睛还是挺瞎的:aru_0160:</p>  145.032113 -37.742463

# %%
from textblob import TextBlob
import re

def preprocess_text(text):
    text = re.sub(r'href=\S+', '', text)
    text = re.sub(r'http\S+', '', text)
    text = re.sub(r'["\']', '', text)
    text = re.sub(r'[^\w\s]', '', text)
    text = text[1:]
    return text


def sentiment_analysis(text):
    blob = TextBlob(text)
    return blob.sentiment.polarity


mas_df['content'] = mas_df['content'].apply(preprocess_text)
mas_df['sentiments'] = mas_df['content'].apply(lambda x: TextBlob(x).sentiment.polarity)
mas_df
# Out:
#                  created_at  \
# 0 2024-05-11 08:27:53+00:00
# 1 2024-05-11 08:27:55+00:00
# 2 2024-05-11 08:27:40+00:00
#
#                                              content   longitude   latitude  \
# 0    Today feels like a good day to see Challengersp  145.013062 -37.902176
# 1  a  relnofollow noopener noreferrer translateno...  144.952333 -37.830720
# 2                 手机里看到的肉眼能看到光在跳舞人类的眼睛还是挺瞎的aru_0160p  145.032113 -37.742463
#
#    sentiments
# 0      0.7000
# 1      0.0125
# 2      0.0000

# %%
weather_df = pd.DataFrame(bom_data)

weather_df = weather_df[['local_date_time_full', 'apparent_t', 'air_temp', 'rain_trace', 'wind_spd_kmh', 'rel_hum', 'vis_km']]

def round_to_nearest_half_hour(dt):
    minute = dt.minute
    if minute < 15:
        return dt.replace(minute=0, second=0)
    elif minute < 45:
        return dt.replace(minute=30, second=0)
    else:
        return dt.replace(minute=0, second=0) + pd.Timedelta(hours=1)
mas_df['created_at'] = pd.to_datetime(mas_df['created_at'])
mas_df['rounded_created_at'] = mas_df['created_at'].apply(round_to_nearest_half_hour)

weather_df['local_date_time_full'] = pd.to_datetime(weather_df['local_date_time_full'], format='%Y%m%d%H%M%S')
weather_df
# Out:
#     local_date_time_full  apparent_t  air_temp rain_trace  wind_spd_kmh  \
# 0    2024-05-11 18:00:00        15.1      16.1        0.0             6
# 1    2024-05-11 17:30:00        15.0      16.5        0.0             9
# 2    2024-05-11 17:00:00        16.0      16.9        0.0             6
# 3    2024-05-11 16:30:00        15.4      17.3        0.0            11
# 4    2024-05-11 16:00:00        16.1      17.7        0.0             9
# ..                   ...         ...       ...        ...           ...
# 158  2024-05-08 20:30:00        13.2      12.6        0.0             0
# 159  2024-05-08 20:00:00        14.0      13.3        0.0             0
# 160  2024-05-08 19:30:00        14.3      13.6        0.0             0
# 161  2024-05-08 19:00:00        14.5      13.8        0.0             0
# 162  2024-05-08 18:30:00        14.6      14.0        0.0             0
#
#      rel_hum vis_km
# 0         69     10
# 1         67     10
# 2         66     10
# 3         64     10
# 4         62     10
# ..       ...    ...
# 158       96     10
# 159       93     10
# 160       91     10
# 161       90     10
# 162       88     10
#
# [163 rows x 7 columns]

# %%
mas_df['rounded_created_at'] = mas_df['rounded_created_at'].dt.tz_localize(None)
mas_df
# Out:
#                  created_at  \
# 0 2024-05-11 08:27:53+00:00
# 1 2024-05-11 08:27:55+00:00
# 2 2024-05-11 08:27:40+00:00
#
#                                              content   longitude   latitude  \
# 0    Today feels like a good day to see Challengersp  145.013062 -37.902176
# 1  a  relnofollow noopener noreferrer translateno...  144.952333 -37.830720
# 2                 手机里看到的肉眼能看到光在跳舞人类的眼睛还是挺瞎的aru_0160p  145.032113 -37.742463
#
#    sentiments  rounded_created_at
# 0      0.7000 2024-05-11 08:30:00
# 1      0.0125 2024-05-11 08:30:00
# 2      0.0000 2024-05-11 08:30:00

# %%
merged_df = pd.merge(mas_df, weather_df, left_on='rounded_created_at', right_on='local_date_time_full', how='inner')

# %%
merged_df.drop(columns=['rounded_created_at', 'local_date_time_full'], inplace=True)
merged_df
# Out:
#                  created_at  \
# 0 2024-05-11 08:27:53+00:00
# 1 2024-05-11 08:27:55+00:00
# 2 2024-05-11 08:27:40+00:00
#
#                                              content   longitude   latitude  \
# 0    Today feels like a good day to see Challengersp  145.013062 -37.902176
# 1  a  relnofollow noopener noreferrer translateno...  144.952333 -37.830720
# 2                 手机里看到的肉眼能看到光在跳舞人类的眼睛还是挺瞎的aru_0160p  145.032113 -37.742463
#
#    sentiments  apparent_t  air_temp rain_trace  wind_spd_kmh  rel_hum vis_km
# 0      0.7000        14.7      13.6        1.8             0      100     10
# 1      0.0125        14.7      13.6        1.8             0      100     10
# 2      0.0000        14.7      13.6        1.8             0      100     10
