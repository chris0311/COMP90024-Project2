# %% [markdown]
# # Harvest data from Mastodon

# %%
from mastodon import Mastodon
import json, time
import pandas as pd
import requests

# For initialization, some server/feature/operation does not need token, while for others, apply for token
m = Mastodon(
    api_base_url=f'https://mastodon.au'
    # use the url of the server such as https://aus.social for https://aus.social/explore
)

# Use timer or loop to achieve streaming harvester, be ware of the frequency
lastid = m.timeline(timeline='public', since_id=None, limit=1, remote=True)[0]['id']
time.sleep(10)
mastodon_data = m.timeline(timeline='public', since_id=lastid, remote=True)
for i in range(len(mastodon_data)):
    print(f"{mastodon_data[i].account.acct}: {mastodon_data[i].id}")
# Out:
# AxiosNews@flipboard.com: 112445135678382726
# anne@toot.cat: 112445135578694593
# wrkmade@threads.net: 112445135464697060

# %% [markdown]
# # Harvest data from BoM

# %%
bom_data = requests.get('http://reg.bom.gov.au/fwo/IDV60901/IDV60901.95936.json').json()['observations']['data']
for i in range(len(bom_data)):
    print(f"{bom_data[i]['local_date_time']} air_temp: {bom_data[i]['air_temp']},apparent_t: {bom_data[i]['apparent_t']},vis_km:{bom_data[i]['vis_km']}, rain_trace:{bom_data[i]['rain_trace']}, rel_hum:{bom_data[i]['rel_hum']}, wind_spd_kmh: {bom_data[i]['wind_spd_kmh']} ")
# Out:
# 15/10:00pm air_temp: 9.9,apparent_t: 9.7,vis_km:10, rain_trace:0.0, rel_hum:94, wind_spd_kmh: 0
# 15/09:30pm air_temp: 10.2,apparent_t: 10.0,vis_km:10, rain_trace:0.0, rel_hum:92, wind_spd_kmh: 0
# 15/09:00pm air_temp: 10.0,apparent_t: 9.8,vis_km:10, rain_trace:0.0, rel_hum:95, wind_spd_kmh: 0
# 15/08:30pm air_temp: 10.1,apparent_t: 9.9,vis_km:10, rain_trace:0.0, rel_hum:93, wind_spd_kmh: 0
# 15/08:00pm air_temp: 10.4,apparent_t: 10.2,vis_km:10, rain_trace:0.0, rel_hum:91, wind_spd_kmh: 0
# 15/07:30pm air_temp: 10.9,apparent_t: 10.6,vis_km:10, rain_trace:0.0, rel_hum:87, wind_spd_kmh: 0
# 15/07:00pm air_temp: 11.5,apparent_t: 11.2,vis_km:10, rain_trace:0.0, rel_hum:83, wind_spd_kmh: 0
# 15/06:30pm air_temp: 12.2,apparent_t: 11.9,vis_km:10, rain_trace:0.0, rel_hum:78, wind_spd_kmh: 0
# 15/06:00pm air_temp: 12.2,apparent_t: 11.9,vis_km:10, rain_trace:0.0, rel_hum:79, wind_spd_kmh: 0
# 15/05:30pm air_temp: 13.2,apparent_t: 12.8,vis_km:10, rain_trace:0.0, rel_hum:72, wind_spd_kmh: 0
# 15/05:00pm air_temp: 14.6,apparent_t: 14.2,vis_km:10, rain_trace:0.0, rel_hum:65, wind_spd_kmh: 0
# 15/04:30pm air_temp: 15.4,apparent_t: 13.5,vis_km:10, rain_trace:0.0, rel_hum:60, wind_spd_kmh: 7
# 15/04:00pm air_temp: 16.0,apparent_t: 14.2,vis_km:10, rain_trace:0.0, rel_hum:59, wind_spd_kmh: 7
# 15/03:30pm air_temp: 16.3,apparent_t: 14.2,vis_km:10, rain_trace:0.0, rel_hum:59, wind_spd_kmh: 9
# 15/03:00pm air_temp: 16.5,apparent_t: 14.4,vis_km:10, rain_trace:0.0, rel_hum:58, wind_spd_kmh: 9
# 15/02:30pm air_temp: 17.0,apparent_t: 15.4,vis_km:10, rain_trace:0.0, rel_hum:55, wind_spd_kmh: 6
# 15/02:00pm air_temp: 16.8,apparent_t: 15.1,vis_km:10, rain_trace:0.0, rel_hum:54, wind_spd_kmh: 6
# 15/01:30pm air_temp: 16.4,apparent_t: 14.5,vis_km:10, rain_trace:0.0, rel_hum:56, wind_spd_kmh: 7
# 15/01:00pm air_temp: 17.0,apparent_t: 15.0,vis_km:10, rain_trace:0.0, rel_hum:52, wind_spd_kmh: 7
# 15/12:30pm air_temp: 16.6,apparent_t: 14.5,vis_km:10, rain_trace:0.0, rel_hum:52, wind_spd_kmh: 7
# 15/12:00pm air_temp: 16.5,apparent_t: 13.8,vis_km:10, rain_trace:0.0, rel_hum:55, wind_spd_kmh: 11
# 15/11:30am air_temp: 15.7,apparent_t: 13.3,vis_km:10, rain_trace:0.0, rel_hum:56, wind_spd_kmh: 9
# 15/11:00am air_temp: 15.6,apparent_t: 14.6,vis_km:10, rain_trace:0.0, rel_hum:64, wind_spd_kmh: 4
# 15/10:30am air_temp: 14.1,apparent_t: 12.2,vis_km:10, rain_trace:0.0, rel_hum:71, wind_spd_kmh: 9
# 15/10:00am air_temp: 12.7,apparent_t: 11.2,vis_km:10, rain_trace:0.0, rel_hum:75, wind_spd_kmh: 6
# 15/09:30am air_temp: 10.6,apparent_t: 8.3,vis_km:10, rain_trace:0.0, rel_hum:80, wind_spd_kmh: 9
# 15/09:00am air_temp: 9.1,apparent_t: 6.6,vis_km:10, rain_trace:0.0, rel_hum:85, wind_spd_kmh: 9
# 15/08:30am air_temp: 7.8,apparent_t: 5.6,vis_km:10, rain_trace:0.0, rel_hum:89, wind_spd_kmh: 7
# 15/08:00am air_temp: 7.0,apparent_t: 4.4,vis_km:10, rain_trace:0.0, rel_hum:93, wind_spd_kmh: 9
# 15/07:30am air_temp: 6.8,apparent_t: 4.2,vis_km:10, rain_trace:0.0, rel_hum:94, wind_spd_kmh: 9
# 15/07:00am air_temp: 7.0,apparent_t: 5.0,vis_km:10, rain_trace:0.0, rel_hum:95, wind_spd_kmh: 6
# 15/06:30am air_temp: 7.0,apparent_t: 4.5,vis_km:10, rain_trace:0.0, rel_hum:97, wind_spd_kmh: 9
# 15/06:00am air_temp: 6.7,apparent_t: 5.9,vis_km:10, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 15/05:30am air_temp: 6.8,apparent_t: 6.1,vis_km:10, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 15/05:00am air_temp: 7.0,apparent_t: 6.3,vis_km:10, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 15/04:30am air_temp: 7.2,apparent_t: 6.6,vis_km:10, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 15/04:00am air_temp: 7.3,apparent_t: 6.7,vis_km:10, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 15/03:30am air_temp: 7.5,apparent_t: 6.9,vis_km:10, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 15/03:00am air_temp: 7.7,apparent_t: 7.2,vis_km:10, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 15/02:30am air_temp: 8.1,apparent_t: 7.3,vis_km:10, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 2
# 15/02:00am air_temp: 8.3,apparent_t: 7.9,vis_km:10, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 15/01:30am air_temp: 8.8,apparent_t: 8.3,vis_km:10, rain_trace:0.0, rel_hum:95, wind_spd_kmh: 0
# 15/01:00am air_temp: 9.4,apparent_t: 7.9,vis_km:10, rain_trace:0.0, rel_hum:94, wind_spd_kmh: 6
# 15/12:30am air_temp: 8.7,apparent_t: 8.3,vis_km:10, rain_trace:0.0, rel_hum:98, wind_spd_kmh: 0
# 15/12:00am air_temp: 9.2,apparent_t: 8.8,vis_km:10, rain_trace:0.0, rel_hum:95, wind_spd_kmh: 0
# 14/11:30pm air_temp: 9.2,apparent_t: 8.9,vis_km:10, rain_trace:0.0, rel_hum:96, wind_spd_kmh: 0
# 14/11:00pm air_temp: 9.7,apparent_t: 8.9,vis_km:10, rain_trace:0.0, rel_hum:91, wind_spd_kmh: 2
# 14/10:30pm air_temp: 10.7,apparent_t: 9.4,vis_km:10, rain_trace:0.0, rel_hum:91, wind_spd_kmh: 6
# 14/10:00pm air_temp: 10.0,apparent_t: 9.4,vis_km:10, rain_trace:0.0, rel_hum:93, wind_spd_kmh: 2
# 14/09:30pm air_temp: 9.6,apparent_t: 9.4,vis_km:10, rain_trace:0.0, rel_hum:96, wind_spd_kmh: 0
# 14/09:00pm air_temp: 9.8,apparent_t: 9.6,vis_km:10, rain_trace:0.0, rel_hum:94, wind_spd_kmh: 0
# 14/08:30pm air_temp: 9.9,apparent_t: 9.6,vis_km:10, rain_trace:0.0, rel_hum:92, wind_spd_kmh: 0
# 14/08:00pm air_temp: 10.2,apparent_t: 9.9,vis_km:10, rain_trace:0.0, rel_hum:89, wind_spd_kmh: 0
# 14/07:30pm air_temp: 10.6,apparent_t: 10.2,vis_km:10, rain_trace:0.0, rel_hum:86, wind_spd_kmh: 0
# 14/07:00pm air_temp: 11.0,apparent_t: 10.6,vis_km:10, rain_trace:0.0, rel_hum:84, wind_spd_kmh: 0
# 14/06:30pm air_temp: 11.5,apparent_t: 11.1,vis_km:10, rain_trace:0.0, rel_hum:80, wind_spd_kmh: 0
# 14/06:00pm air_temp: 12.3,apparent_t: 11.9,vis_km:10, rain_trace:0.0, rel_hum:76, wind_spd_kmh: 0
# 14/05:30pm air_temp: 13.1,apparent_t: 12.7,vis_km:10, rain_trace:0.0, rel_hum:72, wind_spd_kmh: 0
# 14/05:00pm air_temp: 14.6,apparent_t: 13.4,vis_km:10, rain_trace:0.0, rel_hum:65, wind_spd_kmh: 4
# 14/04:30pm air_temp: 15.3,apparent_t: 13.2,vis_km:10, rain_trace:0.0, rel_hum:63, wind_spd_kmh: 9
# 14/04:00pm air_temp: 15.6,apparent_t: 13.5,vis_km:10, rain_trace:0.0, rel_hum:61, wind_spd_kmh: 9
# 14/03:30pm air_temp: 16.0,apparent_t: 13.3,vis_km:10, rain_trace:0.0, rel_hum:57, wind_spd_kmh: 11
# 14/03:00pm air_temp: 16.1,apparent_t: 13.8,vis_km:10, rain_trace:0.0, rel_hum:57, wind_spd_kmh: 9
# 14/02:30pm air_temp: 16.2,apparent_t: 14.0,vis_km:10, rain_trace:0.0, rel_hum:52, wind_spd_kmh: 7
# 14/02:00pm air_temp: 16.6,apparent_t: 14.4,vis_km:10, rain_trace:0.0, rel_hum:56, wind_spd_kmh: 9
# 14/01:30pm air_temp: 16.1,apparent_t: 13.1,vis_km:10, rain_trace:0.0, rel_hum:57, wind_spd_kmh: 13
# 14/01:00pm air_temp: 16.0,apparent_t: 13.5,vis_km:10, rain_trace:0.0, rel_hum:59, wind_spd_kmh: 11
# 14/12:30pm air_temp: 16.2,apparent_t: 14.0,vis_km:10, rain_trace:0.0, rel_hum:57, wind_spd_kmh: 9
# 14/12:00pm air_temp: 15.8,apparent_t: 13.7,vis_km:10, rain_trace:0.0, rel_hum:61, wind_spd_kmh: 9
# 14/11:30am air_temp: 15.5,apparent_t: 13.2,vis_km:10, rain_trace:0.0, rel_hum:58, wind_spd_kmh: 9
# 14/11:00am air_temp: 15.1,apparent_t: 13.6,vis_km:10, rain_trace:0.0, rel_hum:57, wind_spd_kmh: 4
# 14/10:30am air_temp: 14.8,apparent_t: 12.6,vis_km:10, rain_trace:0.0, rel_hum:57, wind_spd_kmh: 7
# 14/10:00am air_temp: 14.4,apparent_t: 12.6,vis_km:10, rain_trace:0.0, rel_hum:62, wind_spd_kmh: 6
# 14/09:30am air_temp: 13.9,apparent_t: 12.4,vis_km:10, rain_trace:0.0, rel_hum:62, wind_spd_kmh: 4
# 14/09:00am air_temp: 13.8,apparent_t: 11.2,vis_km:10, rain_trace:0.0, rel_hum:60, wind_spd_kmh: 9
# 14/08:30am air_temp: 13.8,apparent_t: 12.1,vis_km:10, rain_trace:0.0, rel_hum:59, wind_spd_kmh: 4
# 14/08:00am air_temp: 13.7,apparent_t: 11.4,vis_km:10, rain_trace:0.0, rel_hum:58, wind_spd_kmh: 7
# 14/07:30am air_temp: 13.6,apparent_t: 10.8,vis_km:10, rain_trace:0.0, rel_hum:57, wind_spd_kmh: 9
# 14/07:00am air_temp: 13.5,apparent_t: 11.1,vis_km:10, rain_trace:0.0, rel_hum:58, wind_spd_kmh: 7
# 14/06:30am air_temp: 13.6,apparent_t: 11.3,vis_km:10, rain_trace:0.0, rel_hum:58, wind_spd_kmh: 7
# 14/06:00am air_temp: 13.5,apparent_t: 11.3,vis_km:10, rain_trace:0.0, rel_hum:57, wind_spd_kmh: 6
# 14/05:30am air_temp: 13.5,apparent_t: 11.1,vis_km:10, rain_trace:0.0, rel_hum:57, wind_spd_kmh: 7
# 14/05:00am air_temp: 13.4,apparent_t: 11.3,vis_km:10, rain_trace:0.0, rel_hum:59, wind_spd_kmh: 6
# 14/04:30am air_temp: 13.4,apparent_t: 11.3,vis_km:10, rain_trace:0.0, rel_hum:61, wind_spd_kmh: 6
# 14/04:00am air_temp: 13.5,apparent_t: 11.4,vis_km:10, rain_trace:0.0, rel_hum:60, wind_spd_kmh: 6
# 14/03:30am air_temp: 13.6,apparent_t: 11.4,vis_km:10, rain_trace:0.0, rel_hum:60, wind_spd_kmh: 7
# 14/03:00am air_temp: 13.7,apparent_t: 11.6,vis_km:10, rain_trace:0.0, rel_hum:59, wind_spd_kmh: 6
# 14/02:30am air_temp: 13.7,apparent_t: 11.9,vis_km:10, rain_trace:0.0, rel_hum:58, wind_spd_kmh: 4
# 14/02:00am air_temp: 13.7,apparent_t: 11.6,vis_km:10, rain_trace:0.0, rel_hum:58, wind_spd_kmh: 6
# 14/01:30am air_temp: 13.8,apparent_t: 11.9,vis_km:10, rain_trace:0.0, rel_hum:63, wind_spd_kmh: 6
# 14/01:00am air_temp: 13.8,apparent_t: 12.8,vis_km:10, rain_trace:0.0, rel_hum:65, wind_spd_kmh: 2
# 14/12:30am air_temp: 13.7,apparent_t: 12.6,vis_km:10, rain_trace:0.0, rel_hum:64, wind_spd_kmh: 2
# 14/12:00am air_temp: 13.8,apparent_t: 12.9,vis_km:10, rain_trace:0.0, rel_hum:66, wind_spd_kmh: 2
# 13/11:30pm air_temp: 13.9,apparent_t: 12.3,vis_km:10, rain_trace:0.0, rel_hum:68, wind_spd_kmh: 6
# 13/11:00pm air_temp: 14.1,apparent_t: 12.4,vis_km:10, rain_trace:0.0, rel_hum:68, wind_spd_kmh: 7
# 13/10:30pm air_temp: 13.9,apparent_t: 13.2,vis_km:10, rain_trace:0.0, rel_hum:70, wind_spd_kmh: 2
# 13/10:00pm air_temp: 14.1,apparent_t: 13.1,vis_km:10, rain_trace:0.0, rel_hum:70, wind_spd_kmh: 4
# 13/09:30pm air_temp: 14.4,apparent_t: 13.2,vis_km:10, rain_trace:0.0, rel_hum:73, wind_spd_kmh: 6
# 13/09:00pm air_temp: 14.5,apparent_t: 13.1,vis_km:10, rain_trace:0.0, rel_hum:73, wind_spd_kmh: 7
# 13/08:30pm air_temp: 14.7,apparent_t: 14.0,vis_km:10, rain_trace:0.0, rel_hum:73, wind_spd_kmh: 4
# 13/08:00pm air_temp: 15.3,apparent_t: 14.3,vis_km:10, rain_trace:0.0, rel_hum:76, wind_spd_kmh: 7
# 13/07:30pm air_temp: 15.6,apparent_t: 15.2,vis_km:10, rain_trace:0.0, rel_hum:84, wind_spd_kmh: 7
# 13/07:00pm air_temp: 16.2,apparent_t: 15.1,vis_km:10, rain_trace:0.0, rel_hum:75, wind_spd_kmh: 9
# 13/06:30pm air_temp: 15.9,apparent_t: 16.2,vis_km:10, rain_trace:0.0, rel_hum:79, wind_spd_kmh: 2
# 13/06:00pm air_temp: 15.4,apparent_t: 15.7,vis_km:10, rain_trace:0.0, rel_hum:82, wind_spd_kmh: 2
# 13/05:30pm air_temp: 16.2,apparent_t: 16.5,vis_km:10, rain_trace:0.0, rel_hum:77, wind_spd_kmh: 2
# 13/05:00pm air_temp: 16.5,apparent_t: 17.1,vis_km:10, rain_trace:0.0, rel_hum:74, wind_spd_kmh: 0
# 13/04:30pm air_temp: 16.7,apparent_t: 17.3,vis_km:10, rain_trace:0.0, rel_hum:73, wind_spd_kmh: 0
# 13/04:00pm air_temp: 16.7,apparent_t: 16.4,vis_km:10, rain_trace:0.0, rel_hum:72, wind_spd_kmh: 4
# 13/03:30pm air_temp: 17.0,apparent_t: 16.3,vis_km:10, rain_trace:0.0, rel_hum:70, wind_spd_kmh: 6
# 13/03:00pm air_temp: 17.3,apparent_t: 16.0,vis_km:10, rain_trace:0.0, rel_hum:67, wind_spd_kmh: 9
# 13/02:30pm air_temp: 18.5,apparent_t: 17.8,vis_km:10, rain_trace:0.0, rel_hum:63, wind_spd_kmh: 6
# 13/02:00pm air_temp: 16.9,apparent_t: 16.4,vis_km:10, rain_trace:0.0, rel_hum:73, wind_spd_kmh: 6
# 13/01:30pm air_temp: 15.5,apparent_t: 14.0,vis_km:10, rain_trace:0.0, rel_hum:79, wind_spd_kmh: 11
# 13/01:00pm air_temp: 14.4,apparent_t: 12.8,vis_km:10, rain_trace:0.0, rel_hum:84, wind_spd_kmh: 11
# 13/12:30pm air_temp: 15.6,apparent_t: 14.3,vis_km:10, rain_trace:0.0, rel_hum:75, wind_spd_kmh: 9
# 13/12:00pm air_temp: 17.8,apparent_t: 16.3,vis_km:10, rain_trace:0.0, rel_hum:63, wind_spd_kmh: 9
# 13/11:30am air_temp: 17.9,apparent_t: 18.2,vis_km:10, rain_trace:0.0, rel_hum:63, wind_spd_kmh: 0
# 13/11:00am air_temp: 18.2,apparent_t: 17.9,vis_km:10, rain_trace:0.0, rel_hum:65, wind_spd_kmh: 4
# 13/10:30am air_temp: 16.0,apparent_t: 14.9,vis_km:10, rain_trace:0.0, rel_hum:70, wind_spd_kmh: 7
# 13/10:00am air_temp: 14.6,apparent_t: 13.6,vis_km:10, rain_trace:0.0, rel_hum:76, wind_spd_kmh: 6
# 13/09:30am air_temp: 12.8,apparent_t: 11.1,vis_km:10, rain_trace:0.0, rel_hum:82, wind_spd_kmh: 9
# 13/09:00am air_temp: 11.6,apparent_t: 9.9,vis_km:10, rain_trace:0.0, rel_hum:88, wind_spd_kmh: 9
# 13/08:30am air_temp: 10.6,apparent_t: 8.9,vis_km:10, rain_trace:0.0, rel_hum:95, wind_spd_kmh: 9
# 13/08:00am air_temp: 9.6,apparent_t: 8.2,vis_km:10, rain_trace:0.0, rel_hum:99, wind_spd_kmh: 7
# 13/07:30am air_temp: 9.3,apparent_t: 7.5,vis_km:10, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 9
# 13/07:00am air_temp: 9.3,apparent_t: 7.8,vis_km:10, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 7
# 13/06:30am air_temp: 9.5,apparent_t: 8.1,vis_km:10, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 7
# 13/06:00am air_temp: 9.7,apparent_t: 8.3,vis_km:10, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 7
# 13/05:30am air_temp: 9.5,apparent_t: 8.7,vis_km:10, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 4
# 13/05:00am air_temp: 9.8,apparent_t: 8.1,vis_km:10, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 9
# 13/04:30am air_temp: 9.9,apparent_t: 8.6,vis_km:10, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 7
# 13/04:00am air_temp: 10.0,apparent_t: 8.7,vis_km:10, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 7
# 13/03:30am air_temp: 10.4,apparent_t: 9.4,vis_km:10, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 6
# 13/03:00am air_temp: 10.6,apparent_t: 9.5,vis_km:10, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 7
# 13/02:30am air_temp: 10.3,apparent_t: 10.4,vis_km:9, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 13/02:00am air_temp: 10.6,apparent_t: 10.8,vis_km:10, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 13/01:59am air_temp: 10.6,apparent_t: 10.8,vis_km:10, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 13/01:44am air_temp: 10.5,apparent_t: 10.7,vis_km:7, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 13/01:30am air_temp: 10.6,apparent_t: 10.8,vis_km:9, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 13/01:00am air_temp: 10.9,apparent_t: 11.2,vis_km:10, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 13/12:30am air_temp: 11.0,apparent_t: 11.3,vis_km:9, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 13/12:00am air_temp: 11.3,apparent_t: 11.7,vis_km:10, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 12/11:30pm air_temp: 11.9,apparent_t: 12.5,vis_km:10, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 0
# 12/11:00pm air_temp: 12.2,apparent_t: 12.5,vis_km:10, rain_trace:0.0, rel_hum:100, wind_spd_kmh: 2

# %% [markdown]
# # Data preprocessing

# %%
mas_df = pd.DataFrame(mastodon_data)

# %%
import fiona
from shapely.geometry import shape, Point
import random

with fiona.open("geo/melbourne.geojson", "r") as geojson:
    features = [feature for feature in geojson]

melbourne_polygon = shape(features[0]['geometry'])
for feature in features[1:]:
    melbourne_polygon = melbourne_polygon.union(shape(feature['geometry']))

def generate_random_points_in_polygon(poly, num_points):
    minx, miny, maxx, maxy = poly.bounds
    points = []
    while len(points) < num_points:
        p = Point(random.uniform(minx, maxx), random.uniform(miny, maxy))
        if poly.contains(p):
            points.append(p)
    return points

num = len(mas_df)
random_points = generate_random_points_in_polygon(melbourne_polygon, num)

x_coords = [point.x for point in random_points]
y_coords = [point.y for point in random_points]

mas_df['longitude'] = x_coords
mas_df['latitude'] = y_coords

# %%
mas_df = mas_df[['created_at', 'content', 'longitude', 'latitude']]
mas_df
# Out:
#                  created_at  \
# 0 2024-05-15 12:34:50+00:00
# 1 2024-05-15 12:36:32+00:00
# 2 2024-05-15 12:31:15+00:00
#
#                                              content   longitude   latitude
# 0  <p>Biden challenges Trump to summer presidenti...  144.962823 -37.803731
# 1  <p>Flossing after eating a chia seed bagel is ...  144.956855 -37.820025
# 2  <p>Braun Lectron Hobby Set Radio (Gray Control...  145.028302 -37.990486

# %%
from textblob import TextBlob
import re

def preprocess_text(text):
    text = re.sub(r'href=\S+', '', text)
    text = re.sub(r'http\S+', '', text)
    text = re.sub(r'["\']', '', text)
    text = re.sub(r'[^\w\s]', '', text)
    text = text[1:]
    return text


def sentiment_analysis(text):
    blob = TextBlob(text)
    return blob.sentiment.polarity


mas_df['content'] = mas_df['content'].apply(preprocess_text)
mas_df['sentiments'] = mas_df['content'].apply(lambda x: TextBlob(x).sentiment.polarity)
mas_df
# Out:
#                  created_at  \
# 0 2024-05-15 12:34:50+00:00
# 1 2024-05-15 12:36:32+00:00
# 2 2024-05-15 12:31:15+00:00
#
#                                              content   longitude   latitude  \
# 0  Biden challenges Trump to summer presidential ...  144.962823 -37.803731
# 1  Flossing after eating a chia seed bagel is lik...  144.956855 -37.820025
# 2  Braun Lectron Hobby Set Radio Gray Controls  D...  145.028302 -37.990486
#
#    sentiments
# 0         0.0
# 1         0.0
# 2         0.0

# %%
weather_df = pd.DataFrame(bom_data)

weather_df = weather_df[['local_date_time_full', 'apparent_t', 'air_temp', 'rain_trace', 'wind_spd_kmh', 'rel_hum', 'vis_km']]

def round_to_nearest_half_hour(dt):
    minute = dt.minute
    if minute < 15:
        return dt.replace(minute=0, second=0)
    elif minute < 45:
        return dt.replace(minute=30, second=0)
    else:
        return dt.replace(minute=0, second=0) + pd.Timedelta(hours=1)
mas_df['created_at'] = pd.to_datetime(mas_df['created_at'])
mas_df['rounded_created_at'] = mas_df['created_at'].apply(round_to_nearest_half_hour)

weather_df['local_date_time_full'] = pd.to_datetime(weather_df['local_date_time_full'], format='%Y%m%d%H%M%S')
weather_df
# Out:
#     local_date_time_full  apparent_t  air_temp rain_trace  wind_spd_kmh  \
# 0    2024-05-15 22:00:00         9.7       9.9        0.0             0
# 1    2024-05-15 21:30:00        10.0      10.2        0.0             0
# 2    2024-05-15 21:00:00         9.8      10.0        0.0             0
# 3    2024-05-15 20:30:00         9.9      10.1        0.0             0
# 4    2024-05-15 20:00:00        10.2      10.4        0.0             0
# ..                   ...         ...       ...        ...           ...
# 140  2024-05-13 01:00:00        11.2      10.9        0.0             0
# 141  2024-05-13 00:30:00        11.3      11.0        0.0             0
# 142  2024-05-13 00:00:00        11.7      11.3        0.0             0
# 143  2024-05-12 23:30:00        12.5      11.9        0.0             0
# 144  2024-05-12 23:00:00        12.5      12.2        0.0             2
#
#      rel_hum vis_km
# 0         94     10
# 1         92     10
# 2         95     10
# 3         93     10
# 4         91     10
# ..       ...    ...
# 140      100     10
# 141      100      9
# 142      100     10
# 143      100     10
# 144      100     10
#
# [145 rows x 7 columns]

# %%
mas_df['rounded_created_at'] = mas_df['rounded_created_at'].dt.tz_localize(None)
mas_df
# Out:
#                  created_at  \
# 0 2024-05-15 12:34:50+00:00
# 1 2024-05-15 12:36:32+00:00
# 2 2024-05-15 12:31:15+00:00
#
#                                              content   longitude   latitude  \
# 0  Biden challenges Trump to summer presidential ...  144.962823 -37.803731
# 1  Flossing after eating a chia seed bagel is lik...  144.956855 -37.820025
# 2  Braun Lectron Hobby Set Radio Gray Controls  D...  145.028302 -37.990486
#
#    sentiments  rounded_created_at
# 0         0.0 2024-05-15 12:30:00
# 1         0.0 2024-05-15 12:30:00
# 2         0.0 2024-05-15 12:30:00

# %%
merged_df = pd.merge(mas_df, weather_df, left_on='rounded_created_at', right_on='local_date_time_full', how='inner')

# %%
merged_df.drop(columns=['rounded_created_at', 'local_date_time_full'], inplace=True)
merged_df
# Out:
#                  created_at  \
# 0 2024-05-15 12:34:50+00:00
# 1 2024-05-15 12:36:32+00:00
# 2 2024-05-15 12:31:15+00:00
#
#                                              content   longitude   latitude  \
# 0  Biden challenges Trump to summer presidential ...  144.962823 -37.803731
# 1  Flossing after eating a chia seed bagel is lik...  144.956855 -37.820025
# 2  Braun Lectron Hobby Set Radio Gray Controls  D...  145.028302 -37.990486
#
#    sentiments  apparent_t  air_temp rain_trace  wind_spd_kmh  rel_hum vis_km
# 0         0.0        14.5      16.6        0.0             7       52     10
# 1         0.0        14.5      16.6        0.0             7       52     10
# 2         0.0        14.5      16.6        0.0             7       52     10

# %%
import geopandas as gpd
from shapely.geometry import Point

sa2_gdf = gpd.read_file('geo/SA2_2021_AUST_SHP_GDA2020/SA2_2021_AUST_GDA2020.shp')
sa2_gdf = sa2_gdf[['SA2_CODE21', 'geometry','SA2_NAME21']]

geometry = [Point(xy) for xy in zip(merged_df['longitude'], merged_df['latitude'])]
geo_df = gpd.GeoDataFrame(merged_df, geometry=geometry)

geo_df.crs = sa2_gdf.crs

merged_df = gpd.sjoin(geo_df, sa2_gdf, how='left', op='within')

merged_df
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py:3309: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#                  created_at  \
# 0 2024-05-15 12:34:50+00:00
# 1 2024-05-15 12:36:32+00:00
# 2 2024-05-15 12:31:15+00:00
#
#                                              content   longitude   latitude  \
# 0  Biden challenges Trump to summer presidential ...  144.962823 -37.803731
# 1  Flossing after eating a chia seed bagel is lik...  144.956855 -37.820025
# 2  Braun Lectron Hobby Set Radio Gray Controls  D...  145.028302 -37.990486
#
#    sentiments  apparent_t  air_temp rain_trace  wind_spd_kmh  rel_hum vis_km  \
# 0         0.0        14.5      16.6        0.0             7       52     10
# 1         0.0        14.5      16.6        0.0             7       52     10
# 2         0.0        14.5      16.6        0.0             7       52     10
#
#                       geometry  index_right SA2_CODE21            SA2_NAME21
# 0  POINT (144.96282 -37.80373)          771  206041117               Carlton
# 1  POINT (144.95686 -37.82002)          781  206041505  Melbourne CBD - West
# 2  POINT (145.02830 -37.99049)          833  208011168             Beaumaris

# %%
import pandas as pd
import json

with open('sa2.json', 'r') as file:
    age = json.load(file)

sa2_data = []
for feature in age['features']:
    sa2_code = feature['properties']['sa2_code_2021']
    median_age = feature['properties']['median_age_persons']
    sa2_data.append({'SA2_CODE21': sa2_code, 'median_age': median_age})

sa2_df = pd.DataFrame(sa2_data)

merged_df = pd.merge(merged_df, sa2_df, on='SA2_CODE21', how='left')

# %%
merged_df
# Out:
#                  created_at  \
# 0 2024-05-15 12:34:50+00:00
# 1 2024-05-15 12:36:32+00:00
# 2 2024-05-15 12:31:15+00:00
#
#                                              content   longitude   latitude  \
# 0  Biden challenges Trump to summer presidential ...  144.962823 -37.803731
# 1  Flossing after eating a chia seed bagel is lik...  144.956855 -37.820025
# 2  Braun Lectron Hobby Set Radio Gray Controls  D...  145.028302 -37.990486
#
#    sentiments  apparent_t  air_temp rain_trace  wind_spd_kmh  rel_hum vis_km  \
# 0         0.0        14.5      16.6        0.0             7       52     10
# 1         0.0        14.5      16.6        0.0             7       52     10
# 2         0.0        14.5      16.6        0.0             7       52     10
#
#                       geometry  index_right SA2_CODE21            SA2_NAME21  \
# 0  POINT (144.96282 -37.80373)          771  206041117               Carlton
# 1  POINT (144.95686 -37.82002)          781  206041505  Melbourne CBD - West
# 2  POINT (145.02830 -37.99049)          833  208011168             Beaumaris
#
#    median_age
# 0        27.0
# 1        29.0
# 2        47.0
