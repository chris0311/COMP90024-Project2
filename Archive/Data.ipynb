# %%
# Obtain data from the Mastodon server and output the account number and ID of each status.
# Get weather data from BOM and output the local date time, temperature and wind speed for each piece of data.
# Plot weather data from the BOM as a line chart. 
# Gets air data from the EPA API and outputs the response status code and content.
# Use the sample data to draw line charts, bar charts, and heat maps, and add the heat map layer to the Folium map.
# 
# Mastodon ref:
#     code: https://gitlab.unimelb.edu.au/feit-comp90024/comp90024/-/tree/master/fission/functions/mharvester 
#     tutorial: https://gitlab.unimelb.edu.au/feit-comp90024/comp90024/-/tree/master/fission?ref_type=heads#mastodon-harvester
#     document: https://mastodonpy.readthedocs.io/en/stable/index.html

from mastodon import Mastodon
import json, time

# For initialization, some server/feature/operation does not need token, while for others, apply for token
m = Mastodon(
    api_base_url=f'https://mastodon.au'
    # use the url of the server such as https://aus.social for https://aus.social/explore
)

# Use timer or loop to achieve streaming harvester, be ware of the frequency
lastid = m.timeline(timeline='public', since_id=None, limit=1, remote=True)[0]['id']
time.sleep(10)
mastodon_data = m.timeline(timeline='public', since_id=lastid, remote=True)
for i in range(len(mastodon_data)):
    print(f"{mastodon_data[i].account.acct}: {mastodon_data[i].id}")
# while(1):
#     data = m.timeline(timeline='public', since_id=lastid, remote=True)
#     lastid = lastid if not data else data[-1]['id']
#     print(m.status(lastid))
#     time.sleep(1)
# Out:
# HairyHypnotist@mastodon.hypnoguys.com: 112461515594020365
# PhilippeBoey@mastodon-belgium.be: 112461515372796251
# novajxoj@esperanto.masto.host: 112461515261221883

# %%
# BOM ref:
#     code: https://gitlab.unimelb.edu.au/feit-comp90024/comp90024/-/blob/master/fission/functions/wharvestersimple.py
#     tutorial: https://gitlab.unimelb.edu.au/feit-comp90024/comp90024/-/tree/master/fission?ref_type=heads#harvesting-requests
#     document: http://www.bom.gov.au/catalogue/observations/about-weather-observations.shtml

import json, requests

# This one should be enough to use, change the url to find more data
# For lastest data, check if the json format exists in the source of data
# For historical data, you can download the needed csv and process them
# Historical data example: https://reg.bom.gov.au/climate/dwo/IDCJDW3050.latest.shtml
bom_data = requests.get('http://reg.bom.gov.au/fwo/IDV60901/IDV60901.95936.json').json()['observations']['data']
for i in range(len(bom_data)):
    print(f"{bom_data[i]['local_date_time']} air_temp: {bom_data[i]['air_temp']}, wind_spd_kmh: {bom_data[i]['wind_spd_kmh']}")
# Out:
# 18/07:30pm air_temp: 8.0, wind_spd_kmh: 0
# 18/07:00pm air_temp: 8.4, wind_spd_kmh: 0
# 18/06:30pm air_temp: 9.0, wind_spd_kmh: 2
# 18/06:00pm air_temp: 10.0, wind_spd_kmh: 0
# 18/05:30pm air_temp: 11.1, wind_spd_kmh: 4
# 18/05:00pm air_temp: 11.7, wind_spd_kmh: 7
# 18/04:30pm air_temp: 12.4, wind_spd_kmh: 7
# 18/04:00pm air_temp: 12.9, wind_spd_kmh: 7
# 18/03:30pm air_temp: 13.3, wind_spd_kmh: 13
# 18/03:00pm air_temp: 13.3, wind_spd_kmh: 11
# 18/02:30pm air_temp: 13.4, wind_spd_kmh: 11
# 18/02:00pm air_temp: 13.9, wind_spd_kmh: 9
# 18/01:30pm air_temp: 13.4, wind_spd_kmh: 15
# 18/01:00pm air_temp: 13.6, wind_spd_kmh: 11
# 18/12:30pm air_temp: 13.2, wind_spd_kmh: 9
# 18/12:00pm air_temp: 13.1, wind_spd_kmh: 13
# 18/11:30am air_temp: 12.8, wind_spd_kmh: 11
# 18/11:00am air_temp: 12.5, wind_spd_kmh: 13
# 18/10:30am air_temp: 12.0, wind_spd_kmh: 13
# 18/10:00am air_temp: 11.8, wind_spd_kmh: 11
# 18/09:30am air_temp: 11.1, wind_spd_kmh: 9
# 18/09:00am air_temp: 10.6, wind_spd_kmh: 9
# 18/08:30am air_temp: 9.7, wind_spd_kmh: 9
# 18/08:00am air_temp: 8.8, wind_spd_kmh: 7
# 18/07:30am air_temp: 8.0, wind_spd_kmh: 4
# 18/07:00am air_temp: 9.1, wind_spd_kmh: 7
# 18/06:30am air_temp: 9.4, wind_spd_kmh: 9
# 18/06:00am air_temp: 9.7, wind_spd_kmh: 9
# 18/05:30am air_temp: 9.9, wind_spd_kmh: 11
# 18/05:00am air_temp: 10.0, wind_spd_kmh: 11
# 18/04:30am air_temp: 10.2, wind_spd_kmh: 13
# 18/04:00am air_temp: 10.3, wind_spd_kmh: 11
# 18/03:30am air_temp: 10.3, wind_spd_kmh: 11
# 18/03:00am air_temp: 10.3, wind_spd_kmh: 11
# 18/02:30am air_temp: 10.4, wind_spd_kmh: 11
# 18/02:00am air_temp: 9.9, wind_spd_kmh: 7
# 18/01:30am air_temp: 9.7, wind_spd_kmh: 7
# 18/01:00am air_temp: 10.6, wind_spd_kmh: 13
# 18/12:30am air_temp: 11.0, wind_spd_kmh: 13
# 18/12:00am air_temp: 10.7, wind_spd_kmh: 13
# 17/11:30pm air_temp: 10.9, wind_spd_kmh: 11
# 17/11:00pm air_temp: 11.7, wind_spd_kmh: 15
# 17/10:30pm air_temp: 11.2, wind_spd_kmh: 9
# 17/10:00pm air_temp: 11.6, wind_spd_kmh: 11
# 17/09:30pm air_temp: 11.3, wind_spd_kmh: 11
# 17/09:00pm air_temp: 10.9, wind_spd_kmh: 13
# 17/08:30pm air_temp: 11.5, wind_spd_kmh: 6
# 17/08:00pm air_temp: 12.1, wind_spd_kmh: 11
# 17/07:30pm air_temp: 12.5, wind_spd_kmh: 19
# 17/07:00pm air_temp: 13.4, wind_spd_kmh: 13
# 17/06:30pm air_temp: 13.4, wind_spd_kmh: 11
# 17/06:00pm air_temp: 13.4, wind_spd_kmh: 13
# 17/05:30pm air_temp: 13.4, wind_spd_kmh: 13
# 17/05:00pm air_temp: 13.8, wind_spd_kmh: 13
# 17/04:30pm air_temp: 14.1, wind_spd_kmh: 15
# 17/04:00pm air_temp: 13.8, wind_spd_kmh: 13
# 17/03:30pm air_temp: 12.9, wind_spd_kmh: 11
# 17/03:28pm air_temp: 12.9, wind_spd_kmh: 11
# 17/03:02pm air_temp: 12.6, wind_spd_kmh: 17
# 17/03:00pm air_temp: 12.7, wind_spd_kmh: 17
# 17/02:30pm air_temp: 13.0, wind_spd_kmh: 19
# 17/02:00pm air_temp: 15.2, wind_spd_kmh: 11
# 17/01:30pm air_temp: 15.4, wind_spd_kmh: 9
# 17/01:00pm air_temp: 15.1, wind_spd_kmh: 4
# 17/12:30pm air_temp: 14.9, wind_spd_kmh: 9
# 17/12:00pm air_temp: 15.3, wind_spd_kmh: 6
# 17/11:30am air_temp: 15.4, wind_spd_kmh: 6
# 17/11:00am air_temp: 15.4, wind_spd_kmh: 9
# 17/10:30am air_temp: 15.4, wind_spd_kmh: 7
# 17/10:00am air_temp: 13.7, wind_spd_kmh: 9
# 17/09:30am air_temp: 13.3, wind_spd_kmh: 11
# 17/09:00am air_temp: 12.2, wind_spd_kmh: 9
# 17/08:30am air_temp: 10.3, wind_spd_kmh: 0
# 17/08:00am air_temp: 9.4, wind_spd_kmh: 0
# 17/07:30am air_temp: 8.6, wind_spd_kmh: 2
# 17/07:00am air_temp: 8.3, wind_spd_kmh: 4
# 17/06:30am air_temp: 7.8, wind_spd_kmh: 0
# 17/06:00am air_temp: 8.0, wind_spd_kmh: 0
# 17/05:30am air_temp: 7.9, wind_spd_kmh: 2
# 17/05:00am air_temp: 7.7, wind_spd_kmh: 0
# 17/04:30am air_temp: 8.0, wind_spd_kmh: 0
# 17/04:00am air_temp: 8.3, wind_spd_kmh: 0
# 17/03:30am air_temp: 8.2, wind_spd_kmh: 0
# 17/03:00am air_temp: 8.2, wind_spd_kmh: 0
# 17/02:30am air_temp: 8.5, wind_spd_kmh: 0
# 17/02:00am air_temp: 9.3, wind_spd_kmh: 7
# 17/01:30am air_temp: 9.5, wind_spd_kmh: 7
# 17/01:00am air_temp: 9.5, wind_spd_kmh: 7
# 17/12:30am air_temp: 9.7, wind_spd_kmh: 7
# 17/12:00am air_temp: 10.1, wind_spd_kmh: 7
# 16/11:30pm air_temp: 10.2, wind_spd_kmh: 7
# 16/11:00pm air_temp: 10.6, wind_spd_kmh: 6
# 16/10:30pm air_temp: 11.0, wind_spd_kmh: 9
# 16/10:00pm air_temp: 10.5, wind_spd_kmh: 0
# 16/09:30pm air_temp: 10.8, wind_spd_kmh: 0
# 16/09:00pm air_temp: 10.5, wind_spd_kmh: 0
# 16/08:30pm air_temp: 10.6, wind_spd_kmh: 0
# 16/08:00pm air_temp: 10.7, wind_spd_kmh: 0
# 16/07:30pm air_temp: 11.1, wind_spd_kmh: 0
# 16/07:00pm air_temp: 11.4, wind_spd_kmh: 0
# 16/06:30pm air_temp: 12.3, wind_spd_kmh: 0
# 16/06:00pm air_temp: 12.6, wind_spd_kmh: 0
# 16/05:30pm air_temp: 13.4, wind_spd_kmh: 0
# 16/05:00pm air_temp: 15.3, wind_spd_kmh: 0
# 16/04:30pm air_temp: 16.6, wind_spd_kmh: 2
# 16/04:00pm air_temp: 17.4, wind_spd_kmh: 2
# 16/03:30pm air_temp: 17.4, wind_spd_kmh: 4
# 16/03:00pm air_temp: 17.2, wind_spd_kmh: 7
# 16/02:30pm air_temp: 17.3, wind_spd_kmh: 9
# 16/02:00pm air_temp: 17.4, wind_spd_kmh: 6
# 16/01:30pm air_temp: 17.3, wind_spd_kmh: 6
# 16/01:00pm air_temp: 17.2, wind_spd_kmh: 4
# 16/12:30pm air_temp: 16.7, wind_spd_kmh: 6
# 16/12:00pm air_temp: 16.3, wind_spd_kmh: 4
# 16/11:30am air_temp: 16.3, wind_spd_kmh: 0
# 16/11:00am air_temp: 14.7, wind_spd_kmh: 2
# 16/10:30am air_temp: 13.7, wind_spd_kmh: 2
# 16/10:00am air_temp: 12.0, wind_spd_kmh: 7
# 16/09:30am air_temp: 10.9, wind_spd_kmh: 6
# 16/09:00am air_temp: 9.4, wind_spd_kmh: 7
# 16/08:30am air_temp: 7.7, wind_spd_kmh: 9
# 16/08:00am air_temp: 6.8, wind_spd_kmh: 6
# 16/07:30am air_temp: 6.6, wind_spd_kmh: 6
# 16/07:00am air_temp: 6.5, wind_spd_kmh: 7
# 16/06:30am air_temp: 6.8, wind_spd_kmh: 9
# 16/06:00am air_temp: 6.8, wind_spd_kmh: 7
# 16/05:30am air_temp: 7.0, wind_spd_kmh: 6
# 16/05:00am air_temp: 6.8, wind_spd_kmh: 4
# 16/04:30am air_temp: 7.1, wind_spd_kmh: 9
# 16/04:00am air_temp: 7.4, wind_spd_kmh: 7
# 16/03:30am air_temp: 7.8, wind_spd_kmh: 7
# 16/03:00am air_temp: 7.5, wind_spd_kmh: 0
# 16/02:30am air_temp: 7.7, wind_spd_kmh: 0
# 16/02:00am air_temp: 7.9, wind_spd_kmh: 0
# 16/01:30am air_temp: 8.1, wind_spd_kmh: 0
# 16/01:00am air_temp: 8.5, wind_spd_kmh: 0
# 16/12:30am air_temp: 8.7, wind_spd_kmh: 2
# 16/12:00am air_temp: 8.8, wind_spd_kmh: 0
# 15/11:30pm air_temp: 9.0, wind_spd_kmh: 2
# 15/11:00pm air_temp: 9.4, wind_spd_kmh: 0
# 15/10:30pm air_temp: 9.6, wind_spd_kmh: 0
# 15/10:00pm air_temp: 9.9, wind_spd_kmh: 0
# 15/09:30pm air_temp: 10.2, wind_spd_kmh: 0
# 15/09:00pm air_temp: 10.0, wind_spd_kmh: 0
# 15/08:30pm air_temp: 10.1, wind_spd_kmh: 0
# 15/08:00pm air_temp: 10.4, wind_spd_kmh: 0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

times = reversed([bom_data[i]['local_date_time'] for i in range(len(bom_data))])
air_temps = reversed([bom_data[i]['air_temp'] for i in range(len(bom_data))])
wind_spd_kmhs = reversed([bom_data[i]['wind_spd_kmh'] for i in range(len(bom_data))])

data = pd.DataFrame({'Time': times, 'Temperature': air_temps, 'Wind Speed(kmh)': wind_spd_kmhs})

plt.figure(figsize=(12, 6))
sns.lineplot(x='Time', y='Temperature', data=data)
plt.xlabel('Time')
x_ticks = plt.xticks()[0]
x_labels = plt.xticks()[1]
plt.xticks(x_ticks[::24], x_labels[::24])
plt.ylabel('Temperature')
plt.title('Temperature over time')
plt.grid(True)
plt.show()

# %%
import requests

url = "https://gateway.api.epa.vic.gov.au/environmentMonitoring/v1/sites"
params = {"environmentalSegment": "air"}
headers = {
    'User-Agent': 'curl/8.4.0',
    'Cache-Control': 'no-cache',
    'X-API-Key': 'c3a1d847b44c4285b466f3e6751fffb5',
}

response = requests.get(url, params=params, headers=headers)

print(response.status_code)
print(response.text)
# Out:
# 200
# {
#   "totalRecords" : 93,
#   "records" : [
#     {
#       "siteID" : "77062cb7-3e3b-4984-b6d0-03dda76177f2",
#       "siteName" : "Box Hill",
#       "siteType" : "Standard",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.8287277,
#           145.1324
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "PM2.5",
#           "averageValue" : 11.34,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "1021"
#         }
#       ]
#     },
#     {
#       "siteID" : "c69ed768-34d2-4d72-86f3-088c250758a8",
#       "siteName" : "Alphington",
#       "siteType" : "Standard",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.7784081,
#           145.0306
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "PM2.5",
#           "averageValue" : 23.08,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "1021"
#         }
#       ]
#     },
#     {
#       "siteID" : "ee780b50-0240-4c7e-99f8-0df759caf3a3",
#       "siteName" : "Churchill",
#       "siteType" : "Standard",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.3043137,
#           146.414932
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "PM2.5",
#           "averageValue" : 3.96,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "1021"
#         }
#       ]
#     },
#     {
#       "siteID" : "cddf953a-b932-4918-97ea-1d19583d507a",
#       "siteName" : "Traralgon South",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.29585,
#           146.5392
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 6.2,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "70584bae-a7e7-4ae9-adf5-1e8e92b15386",
#       "siteName" : "Traralgon",
#       "siteType" : "Standard",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.1942825,
#           146.531464
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "PM2.5",
#           "averageValue" : 5.33,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "1021"
#         }
#       ]
#     },
#     {
#       "siteID" : "69fa2d5e-557c-457a-9103-21bc2609f5eb",
#       "siteName" : "Tyers North",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.12967,
#           146.4828
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 5.93,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "69088979-01eb-4b48-9535-22b6d69421ec",
#       "siteName" : "Dandenong",
#       "siteType" : "Standard",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.98576,
#           145.1987
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "PM2.5",
#           "averageValue" : 11.92,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "1021"
#         }
#       ]
#     },
#     {
#       "siteID" : "f5c385fd-c136-4398-99b0-35696b711b7b",
#       "siteName" : "Moe",
#       "siteType" : "Standard",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.1864662,
#           146.258331
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "PM2.5",
#           "averageValue" : 5.2,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "1021"
#         }
#       ]
#     },
#     {
#       "siteID" : "dd8279c0-018d-469b-92c7-49eeeecd27de",
#       "siteName" : "Boolarra South",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.44398,
#           146.2742
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 7,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "33fd2638-98ff-4b6c-8b75-5feecae706df",
#       "siteName" : "Traralgon East",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.19631,
#           146.5621
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 6.6,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "1adaf80a-f20f-4fd3-8fa1-60d87acfce61",
#       "siteName" : "Boolarra",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.36981,
#           146.2751
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 6.85,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "aa39a036-4514-4b51-aaf4-6276e98b036c",
#       "siteName" : "Yinnar",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.32779,
#           146.3371
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 6.2,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "032edf91-3cb9-42be-8ff3-70d3f56dba68",
#       "siteName" : "Morwell East",
#       "siteType" : "Standard",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.229393,
#           146.424454
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "PM2.5",
#           "averageValue" : 2.94,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "1021"
#         }
#       ]
#     },
#     {
#       "siteID" : "5fa9b7aa-651d-4c9d-96b1-8f6813b2d933",
#       "siteName" : "Geelong South",
#       "siteType" : "Standard",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.17356,
#           144.3703
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "PM2.5",
#           "averageValue" : 5.95,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "1021"
#         }
#       ]
#     },
#     {
#       "siteID" : "3a0e909b-a278-4c5b-8786-975c5ef4c4c9",
#       "siteName" : "Willow Grove",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.07072,
#           146.1779
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 5.65,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "a4f9fa11-1e9b-45eb-9473-9a8418a1c6bf",
#       "siteName" : "Yallourn North",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.16144,
#           146.3629
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 5.45,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "15b90658-97fe-42a4-8bb8-cfc5cc90cdc9",
#       "siteName" : "Point Cook",
#       "siteType" : "Standard",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.9263153,
#           144.7567
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "PM2.5",
#           "averageValue" : 5.02,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "1021"
#         }
#       ]
#     },
#     {
#       "siteID" : "932e8220-8d30-4e51-9200-e5b1ec8f87fb",
#       "siteName" : "Yinnar",
#       "siteType" : "Standard",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.32676,
#           146.3261
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "PM10",
#           "averageValue" : 0.93,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "1016"
#         }
#       ]
#     },
#     {
#       "siteID" : "7e56abba-a570-4139-ad68-f45033862599",
#       "siteName" : "Flynns Creek",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.24396,
#           146.6362
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 7.3,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "4afe6adc-cbac-4bf1-afbe-ff98d59564f9",
#       "siteName" : "Melbourne CBD",
#       "siteType" : "Standard",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.8073959,
#           144.97
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z"
#         }
#       ]
#     },
#     {
#       "siteID" : "ce30ee54-f7f7-4d34-9708-0762c9f86878",
#       "siteName" : "Tyers",
#       "siteType" : "Camera",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.1300278,
#           146.482513
#         ]
#       },
#       "cameraImageURL" : "https://cmcameras.net.au/images/Tyers/snapshot2.jpg",
#       "timeLapseURL" : "https://cmcameras.net.au/images/Tyers/video.mp4"
#     },
#     {
#       "siteID" : "56a01f92-efd2-4f9f-8ee8-19a2138434bd",
#       "siteName" : "Callignee",
#       "siteType" : "Camera",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.36169,
#           146.588211
#         ]
#       },
#       "cameraImageURL" : "https://cmcameras.net.au/images/Calignee/snapshot3.jpg",
#       "timeLapseURL" : "https://cmcameras.net.au/images/Calignee/video.mp4"
#     },
#     {
#       "siteID" : "63fc308f-baf4-4dd5-9c3e-abe8f996342b",
#       "siteName" : "Hernes Oak",
#       "siteType" : "Camera",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.1853447,
#           146.323441
#         ]
#       },
#       "cameraImageURL" : "https://cmcameras.net.au/images/HernesOak/snapshot1.jpg",
#       "timeLapseURL" : "https://cmcameras.net.au/images/HernesOak/video.mp4"
#     },
#     {
#       "siteID" : "8413d21d-5440-4f2b-81f9-2e5cfb8620d0",
#       "siteName" : "Wangaratta",
#       "siteType" : "Standard",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -36.36926,
#           146.3133
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "PM2.5",
#           "averageValue" : 11.88,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "1021"
#         }
#       ]
#     },
#     {
#       "siteID" : "33f48fb3-f771-49e8-b554-0fcec8eb70bb",
#       "siteName" : "Morwell South",
#       "siteType" : "Standard",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.2392921,
#           146.3873
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "PM2.5",
#           "averageValue" : 6.07,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "1021"
#         }
#       ]
#     },
#     {
#       "siteID" : "d56ede8c-637a-41e9-a055-f53198e9456a",
#       "siteName" : "Brighton",
#       "siteType" : "Standard",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.9135475,
#           144.998
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "PM2.5",
#           "averageValue" : 6.37,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "1021"
#         }
#       ]
#     },
#     {
#       "siteID" : "1ddbf1d8-eb8b-43cd-acca-9c23c29ff338",
#       "siteName" : "Echuca",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -36.12591,
#           144.754288
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z"
#         }
#       ]
#     },
#     {
#       "siteID" : "22b21e76-76f2-4b0d-b133-3fc852c721b5",
#       "siteName" : "Healesville",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.6468239,
#           145.5275
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 6.43,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "3a5e1716-5612-4f3e-a3d6-a924c0899804",
#       "siteName" : "Warrnambool",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.3860931,
#           142.510986
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 5.05,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "48b39f0a-0ea6-4016-b8f2-23adbc72897a",
#       "siteName" : "Mildura",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -34.1635132,
#           142.139374
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 5.3,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "5e9e5f47-e85b-493e-9b39-e6b5f282bc61",
#       "siteName" : "Horsham",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -36.72263,
#           142.175415
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 5.18,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "4c4e8933-a66b-4e76-b2c2-ad9bb56d8809",
#       "siteName" : "Altona North",
#       "siteType" : "Standard",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.8441238,
#           144.861618
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "PM2.5",
#           "averageValue" : 2,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "1021"
#         }
#       ]
#     },
#     {
#       "siteID" : "e47fa291-45de-4b06-b6ac-6bb8bf6421f8",
#       "siteName" : "Ballarat",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.5293274,
#           143.842438
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 5.55,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "b860d407-5227-4b15-a0d9-eb5773b9d083",
#       "siteName" : "Bairnsdale",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.829895,
#           147.620209
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 7.85,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "cda783ad-39fb-4ace-a8cd-15324fdb6147",
#       "siteName" : "Castlemaine",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.0730247,
#           144.233292
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 12.23,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "0ad5e111-20d2-44d8-ad03-efa0736f65fc",
#       "siteName" : "Beechworth",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -36.37299,
#           146.679077
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 5.7,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "ab1a6394-e44b-4ff1-a1c0-cb8a4b48408e",
#       "siteName" : "Benalla",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -36.54932,
#           145.997223
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 11.48,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "39ae637d-9102-49f0-b741-6b280055b033",
#       "siteName" : "Ararat",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.2828064,
#           142.935608
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 5.4,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "883b5df6-8125-4e63-a2b6-1200faac4324",
#       "siteName" : "Cobden",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.32716,
#           143.076
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 6.4,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "b17f9b91-fdcf-43e6-9837-0ae6a775711d",
#       "siteName" : "Camperdown",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.2248344,
#           143.140152
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 5.2,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "36a0e96c-7527-4a78-811c-230205a1640e",
#       "siteName" : "Colac",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.3456841,
#           143.594269
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 5.75,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "57f7b166-7696-4238-8a9b-8a1505e7de8f",
#       "siteName" : "Maffra",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.9596977,
#           146.991745
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 6.6,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "3420cbd3-a860-455b-813d-38656d72ef11",
#       "siteName" : "Gisborne",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.4853172,
#           144.5862
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 4.65,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "8ed3a265-73dc-4458-8977-13cb6f533ef5",
#       "siteName" : "Macedon",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.4230652,
#           144.562225
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 5.23,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "6bfdd604-0c03-4ea3-8783-782a3673441f",
#       "siteName" : "Lancefield",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.2782669,
#           144.73526
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 5.08,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "cc5367e5-58b2-4e08-b9ec-920d9afe72ca",
#       "siteName" : "Kyneton",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.24706,
#           144.451111
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 5.48,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "f9a9a4b6-7067-41d4-93e2-3cc39fb0784b",
#       "siteName" : "Heathcote",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -36.92107,
#           144.709946
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 32.98,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Fair",
#           "healthAdviceColor" : "#EEC900",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "13be38f2-816d-4c99-8d0b-ec59fdcc952f",
#       "siteName" : "Kinglake",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.5337448,
#           145.340515
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z"
#         }
#       ]
#     },
#     {
#       "siteID" : "2108694e-5804-4164-a1c6-7a97d6c82ddb",
#       "siteName" : "Daylesford",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.3410339,
#           144.130463
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 4.93,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "51bff557-dea8-44b3-8ae3-10897be6df61",
#       "siteName" : "Heywood",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.1323051,
#           141.631821
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 6.97,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "262abeb7-7cd3-44ea-abb5-14f80a355bfa",
#       "siteName" : "Hamilton",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.73387,
#           142.020813
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 4.95,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "f3aaef44-43be-4557-b572-5de293dd1d85",
#       "siteName" : "Kerang",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -35.7475281,
#           143.924866
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 4.6,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "bafb0050-7888-4477-bff7-733f1608c8c6",
#       "siteName" : "Lorne",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.5403671,
#           143.9738
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 4.63,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "58da8231-682a-44ce-97ee-17de937c3782",
#       "siteName" : "Mallacoota",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.56016,
#           149.751114
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z"
#         }
#       ]
#     },
#     {
#       "siteID" : "6e1cb2da-1537-40b4-b011-9519095d7e06",
#       "siteName" : "Shepparton",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -36.3808365,
#           145.406616
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 5.75,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "eb624ae2-42e4-49eb-a8e0-025121c9d629",
#       "siteName" : "Orbost",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.7059746,
#           148.456284
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 6.87,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "cfe63589-fcb8-4a85-b500-4920b37f92e7",
#       "siteName" : "Sale",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.102684,
#           147.057541
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 7.6,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "703c0c30-adc6-4e69-94cc-78b8aaa23255",
#       "siteName" : "Myrtleford",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -36.5539742,
#           146.72081
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 11.77,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "6f12e44a-29d7-4ca9-9756-bcb444962af4",
#       "siteName" : "Mansfield",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.0508,
#           146.077087
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 14.95,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "0f58d8a5-4856-4de8-8ce8-5a741e27522c",
#       "siteName" : "Portland",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.3525276,
#           141.6071
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 8.58,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "63f9b336-cf04-41a4-a08b-cbdb2d20a351",
#       "siteName" : "Ouyen",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -35.0655365,
#           142.318649
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 4.88,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "cc0b9034-7758-4c8e-9680-7fc2915fdcb8",
#       "siteName" : "Torquay",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.3079338,
#           144.310516
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 5.3,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "6006c323-1709-4b4f-a048-040f51cc801e",
#       "siteName" : "Wonthaggi",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.5871048,
#           145.578491
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 6.02,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "c7d0c270-8c0e-4f5d-8d3b-cd15e786cbbc",
#       "siteName" : "Warragul",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.1666527,
#           145.941544
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 5.93,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "ea05039d-28a1-4cd4-838a-648a7843059a",
#       "siteName" : "Yarrawonga",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -36.01634,
#           146.013016
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 6.6,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "7c3c27ba-2255-4c0a-b604-94ae63959a51",
#       "siteName" : "Wodonga",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -36.1377754,
#           146.8983
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 5.38,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "a50f4750-b17a-47cd-954b-dc694bd441c2",
#       "siteName" : "Broadford",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.2078857,
#           145.04805
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 10.78,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "fc15d85f-4141-4949-b2ef-e93c5c825205",
#       "siteName" : "Yarra Glen",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.65686,
#           145.373459
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 16.7,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "07967f24-444c-4fd8-901c-9c0c67144053",
#       "siteName" : "Sunbury",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.58954,
#           144.719727
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 5,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "9888bb86-6422-44e6-9f7c-92fc38f2736d",
#       "siteName" : "Lakes Entrance",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.8716469,
#           148.006744
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 4.9,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "3aacf39f-dda4-4716-8db4-58b7ea2767b1",
#       "siteName" : "Leongatha",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.4689522,
#           145.956421
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 6.65,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "1619e162-e4a5-4f96-b6a4-540ecd1a471c",
#       "siteName" : "Bacchus Marsh",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.674633,
#           144.4354
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 5.25,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "27088121-4310-48ce-8d3f-b1ec5c1608c6",
#       "siteName" : "Warburton",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.75449,
#           145.688278
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 5.7,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "8f03fc05-84f0-4aef-befb-37725c9c5d69",
#       "siteName" : "Drysdale",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.1913528,
#           144.550659
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 5.25,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "c2d7348a-918e-444f-9cf1-3f67055cd90a",
#       "siteName" : "Rutherglen",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -36.0538254,
#           146.463989
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 10.68,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "ed97e7b3-1ce6-4c6c-bb45-7f42ef305620",
#       "siteName" : "Bright",
#       "siteType" : "Standard",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -36.73228,
#           146.9702
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "PM2.5",
#           "averageValue" : 4.66,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "1021"
#         }
#       ]
#     },
#     {
#       "siteID" : "fd9971b2-130e-4163-b56c-a37beadc7846",
#       "siteName" : "Macleod",
#       "siteType" : "Standard",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.722477,
#           145.0576
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "PM2.5",
#           "averageValue" : 1.97,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "1021"
#         }
#       ]
#     },
#     {
#       "siteID" : "4246f120-80ff-44e5-9c94-ec5a16a7276e",
#       "siteName" : "Mildura",
#       "siteType" : "Standard",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -34.19561,
#           142.1616
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "PM2.5",
#           "averageValue" : 5.32,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "1021"
#         }
#       ]
#     },
#     {
#       "siteID" : "f70a1ce9-691e-4dff-83e4-792065d77779",
#       "siteName" : "Swan Hill",
#       "siteType" : "Standard",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -35.34331,
#           143.5341
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "PM2.5",
#           "averageValue" : 1.99,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "1021"
#         }
#       ]
#     },
#     {
#       "siteID" : "b2972c05-c6c6-4d50-94ad-7fa53722e9d0",
#       "siteName" : "Spotswood",
#       "siteType" : "Standard",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.82743,
#           144.8801
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "PM2.5",
#           "averageValue" : 1.99,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "1021"
#         }
#       ]
#     },
#     {
#       "siteID" : "0968ba97-5cdf-464a-a8be-8ae789b83f37",
#       "siteName" : "Swan Hill",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -35.34314,
#           143.534088
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 6.38,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "d9c23fd4-2ed0-4627-87a7-4199bffad9b4",
#       "siteName" : "Wallan",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.41652,
#           144.981232
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 5.78,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "63a73778-4244-481b-82d9-3a7c416832eb",
#       "siteName" : "Rosedale",
#       "siteType" : "Standard",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.15588,
#           146.7842
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "PM2.5",
#           "averageValue" : 10.64,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "1021"
#         }
#       ]
#     },
#     {
#       "siteID" : "9a9f2a8f-e108-4ae6-b9d3-ec6fe25863b5",
#       "siteName" : "Kingsville",
#       "siteType" : "Standard",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.81191,
#           144.8741
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "PM2.5",
#           "averageValue" : 2,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "1021"
#         }
#       ]
#     },
#     {
#       "siteID" : "f2190dd1-176f-439f-856d-b7ca1a7b00cd",
#       "siteName" : "Rosedale",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.15044,
#           146.7858
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 7.33,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "86a49d71-03f4-4589-af5a-cc63b730faaf",
#       "siteName" : "Flynn",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.17107,
#           146.6933
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 7.23,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ]
#     },
#     {
#       "siteID" : "3d1a81e7-ef78-4800-80c6-cc7e6ea01cf4",
#       "siteName" : "Glengarry",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.12751,
#           146.5691
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z"
#         }
#       ]
#     },
#     {
#       "siteID" : "ea40fbea-46ce-4acf-8f3e-eb76c26c712b",
#       "siteName" : "Melton",
#       "siteType" : "Standard",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.7064552,
#           144.5669
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "PM2.5",
#           "averageValue" : 3.28,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "1021"
#         }
#       ]
#     },
#     {
#       "siteID" : "9348c1f5-60c5-4c35-b4f1-1f0931ab1415",
#       "siteName" : "Mooroolbark",
#       "siteType" : "Standard",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.77512,
#           145.3284
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "PM2.5",
#           "averageValue" : 14.3,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "1021"
#         }
#       ]
#     },
#     {
#       "siteID" : "031354b3-b6a2-403b-aae3-79e18f69c957",
#       "siteName" : "Footscray",
#       "siteType" : "Standard",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.80266,
#           144.8778
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "PM2.5",
#           "averageValue" : 2,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "1021"
#         }
#       ]
#     },
#     {
#       "siteID" : "78dbc892-d9e9-490b-94a6-baf1ca72c36c",
#       "siteName" : "Brooklyn",
#       "siteType" : "Standard",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.8220978,
#           144.8471
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "PM2.5",
#           "averageValue" : 5.49,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "1021"
#         }
#       ]
#     },
#     {
#       "siteID" : "82e215ca-e0e5-4a00-9357-98d53b04311b",
#       "siteName" : "Bendigo",
#       "siteType" : "Standard",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -36.77841,
#           144.300064
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "PM2.5",
#           "averageValue" : 7.22,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "1021"
#         }
#       ]
#     },
#     {
#       "siteID" : "c21b7785-acfa-45c0-83c6-7700760bf8f1",
#       "siteName" : "Porepunkah",
#       "siteType" : "Incident",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -36.70419,
#           146.9169
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-18T19:00:00Z",
#           "until" : "2024-05-18T20:00:00Z",
#           "healthParameter" : "PM2.5",
#           "averageValue" : 6.32,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "1021"
#         }
#       ]
#     }
#   ]
# }

# %%
import matplotlib.pyplot as plt

# 示例数据
categories = ['A', 'B', 'C', 'D', 'E']
values = [23, 45, 56, 78, 90]

# 绘制柱状图
plt.figure(figsize=(8, 5))
plt.bar(categories, values, color='skyblue')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Chart Example')
plt.show()

# 绘制折线图
plt.figure(figsize=(8, 5))
plt.plot(categories, values, marker='o', color='green', linestyle='-', linewidth=2)
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Line Chart Example')
plt.grid(True)  # 添加网格线
plt.show()

# %%
import folium
from folium.plugins import HeatMap
import numpy as np

melbourne_center = [-37.8136, 144.9631]

m = folium.Map(location=melbourne_center, zoom_start=13, tiles='OpenStreetMap')

num_points = 200
np.random.seed(0)
data = np.array([np.random.uniform(low=-37.85, high=-37.75, size=num_points),
                 np.random.uniform(low=144.85, high=145.05, size=num_points)]).T

HeatMap(data).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3bc9abd16a21461d8dc20ffb077a5cc9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3bc9abd16a21461d8dc20ffb077a5cc9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3bc9abd16a21461d8dc20ffb077a5cc9 = L.map(
#                 &quot;map_3bc9abd16a21461d8dc20ffb077a5cc9&quot;,
#                 {
#                     center: [-37.8136, 144.9631],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d72b0919a293875b5a22faf94a46ef95 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d72b0919a293875b5a22faf94a46ef95.addTo(map_3bc9abd16a21461d8dc20ffb077a5cc9);
#
#
#             var heat_map_7091766ed999b69ab1ad0105d68f824b = L.heatLayer(
#                 [[-37.79511864960727, 144.9123591763988], [-37.77848106336276, 144.9892686977631], [-37.78972366239284, 144.9255503678585], [-37.79551168170031, 144.88592073551192], [-37.80763452006611, 144.85493574567826], [-37.78541058869334, 144.86344992629265], [-37.806241278873735, 144.98587855469972], [-37.76082269992179, 144.9407393689112], [-37.753633723949896, 144.95731584222176], [-37.811655848117425, 145.0293342586081], [-37.770827496191735, 145.04806778947935], [-37.79711050802471, 144.89337939687968], [-37.793195543890604, 144.98261564062003], [-37.75744033617073, 144.90266447534742], [-37.842896394180215, 144.85413019989315], [-37.84128707002985, 145.00167573076723], [-37.84797816025597, 144.91400343016448], [-37.766738015445206, 144.9266927788344], [-37.77218432490501, 144.96766342271073], [-37.76299878517532, 145.01620969104724], [-37.75213816577672, 144.97579636871822], [-37.77008414357833, 145.02453013108948], [-37.803852063774706, 144.90470840696312], [-37.771947082371355, 145.0096093667825], [-37.83817255741311, 144.8871271888612], [-37.78600789786725, 145.0405583313944], [-37.835664671259096, 144.98749765527756], [-37.75553310829504, 144.89310153542272], [-37.79781516782499, 145.0394741180978], [-37.80853380600095, 144.99617116135403], [-37.82354443878954, 144.900788328519], [-37.77257663105658, 144.8926623954735], [-37.80438496677834, 144.95364014278613], [-37.79315660511313, 144.8551325436109], [-37.848121019956366, 144.89149401508823], [-37.788236450292416, 144.9349370937503], [-37.78879042772776, 144.92483399606684], [-37.788306600312524, 144.94271508487296], [-37.755625192148536, 144.90552574125894], [-37.781817970089655, 144.96735686929165], [-37.814049209942624, 145.02277112118466], [-37.80629680462007, 144.8735063711924], [-37.78023688040727, 144.95347582143083], [-37.84397745283707, 144.87641362126902], [-37.78332332845543, 144.99337193623853], [-37.782936213038184, 144.92921194056146], [-37.82896174389262, 144.9630842623717], [-37.83710737023451, 144.8866559672428], [-37.818457164907585, 144.87896955186866], [-37.813628922905735, 144.9476112561298], [-37.792980322958215, 144.92112254756998], [-37.80613984865377, 145.03808638905056], [-37.75116261619408, 145.0030650507614], [-37.8397955189252, 144.9997327239701], [-37.829112324390515, 145.0307439479492], [-37.833869048211504, 144.8666844870884], [-37.78468916745346, 144.9604384939845], [-37.82467083974602, 144.96689521379116], [-37.80336892271437, 145.04238727570944], [-37.82555744079984, 144.9084295053585], [-37.83410304163545, 144.8981657559831], [-37.83896248588357, 144.8700587884531], [-37.78436704105347, 144.8532859259183], [-37.83618170486514, 145.03590586335844], [-37.830341763831996, 144.98398330931818], [-37.81312748293391, 145.00703058240464], [-37.767900677015206, 144.9063460211508], [-37.8402898724207, 144.96728203323727], [-37.76620550925012, 144.86279105322419], [-37.84039015921061, 144.94712551918693], [-37.752354053498664, 145.0454990279489], [-37.803134879835234, 145.02530104906333], [-37.752323891180964, 144.91763179036738], [-37.7895154480255, 145.0423140309083], [-37.77607364206017, 144.89634032529423], [-37.84608122077457, 145.03986376448316], [-37.82171930374236, 145.0382755409413], [-37.837980343878684, 145.00984051747048], [-37.820385980247785, 144.97608958737337], [-37.838127228104575, 145.024857593325], [-37.818201682060604, 144.90860405690157], [-37.808573700548536, 145.0197887110626], [-37.84358525036512, 144.9735753383835], [-37.780752788063, 144.85264737155177], [-37.793339854579344, 144.91944670358643], [-37.823461050906054, 144.87962817218963], [-37.79767519465333, 145.04636587796367], [-37.84060594892416, 144.945674061408], [-37.79240535044438, 144.94947827309974], [-37.75707038024238, 144.97789450327974], [-37.81814310475487, 144.92371692122592], [-37.78325896200363, 144.87738005433712], [-37.83682021375956, 145.01442354663885], [-37.77836727958814
